# %% [markdown]
# <a href="https://colab.research.google.com/github/LaSpi21/CodeWars/blob/main/Torres_de_Hanoi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Trabajo practico Torres de Hanoi
#
# ## Pablo La Spina

# %%
def TorresdeHanoi(n : int, mostrar_torres: bool =True, mostrar_pasos: bool = True) -> int:
    """
    Resuelve el juego de las torres de Hanoi para una cantidad 'n' de discos.
    Representa cada torre como una lista.

    Parámetros:
    - n (int): El número de discos en la torre de origen.
    - mostrar_torres (bool): Indica si se mostrará la representación gráfica de las torres en cada paso (predeterminado: True).
    - silenciada (bool): Indica si se indicarán los pasos (predeterminado: True).

    Retorna:
    - int: La cantidad de pasos (minimos) requeridos para resolver el caso de "n" discos.
    """
    assert isinstance(n, int) and n > 0, "Debe indicarse un numero entero y positivo de discos"
    assert isinstance(mostrar_torres, bool), "La indicación de si se muestran o no las torres durante el procedimiento debe ser un booleano"
    assert isinstance(mostrar_pasos, bool), "La indicación de si se muestran los pasos del procedimiento debe ser un booleano"

    colores = ['\033[36m', '\033[94m', '\033[91m', '\033[92m', '\033[93m', '\033[96m', '\033[95m']
    ori = list(range(n, 0, -1))
    dest = []
    aux = []
    pasos = 0

    def _hanoi(n, origen, destino, auxiliar, nombre_origen="origen", nombre_destino="destino", nombre_aux="auxiliar"):
        nonlocal pasos # Tomamos la variable pasos del wrapper.
        if n == 1:
            disco = origen.pop()
            destino.append(disco)
            pasos += 1
            if mostrar_pasos: print(f"Paso {pasos}: Mover disco {disco} de {nombre_origen} a {nombre_destino}")
            _print_torres(ori, aux, dest, mostrar_torres)
        else:
            _hanoi(n - 1, origen, auxiliar, destino, nombre_origen, nombre_aux, nombre_destino)
            disco = origen.pop()
            destino.append(disco)
            pasos += 1
            if mostrar_pasos: print(f"Paso {pasos}: Mover disco {disco} de {nombre_origen} a {nombre_destino}")
            _print_torres(ori, aux, dest, mostrar_torres)
            _hanoi(n - 1, auxiliar, destino, origen, nombre_aux, nombre_destino, nombre_origen)

    def _print_torres(ori, aux, dest, mostrar_torres):
        if not mostrar_torres:
            return
        print()
        height = max(len(ori), len(aux), len(dest))
        towers = [ori, aux, dest]

        for i in range(n - 1, -1, -1):
            for tower in towers:
                if i < len(tower):
                    disk = tower[i]
                    print('\033[1m' + colores[disk % len(colores)] + ("—" * (disk * 2 - 1)).center(n * 4, " ") + '\033[0m',
                          end="")
                else:
                    print(("|").center(n * 4, " "), end="")
            print()

        print("Origen".center(n * 4, " ") + "Auxiliar".center(n * 4, " ") + "Destino".center(n * 4, " "))
        print()
        print()

    _print_torres(ori, aux, dest, mostrar_torres)
    _hanoi(n, ori, dest, aux)

    if mostrar_pasos: print("Una torre de Hanoi de", n, "discos puede resolverse en", pasos, "pasos.")
    return pasos

# %%
#Algunos ejemplos:
TorresdeHanoi(3)
# Out:
#      —           |           |
#     ———          |           |
#    —————         |           |
#    Origen     Auxiliar    Destino
#
#
# Paso 1: Mover disco 1 de origen a destino
#
#      |           |           |
#     ———          |           |
#    —————         |           —
#    Origen     Auxiliar    Destino
#
#
# Paso 2: Mover disco 2 de origen a auxiliar
#
#      |           |           |
#      |           |           |
#    —————        ———          —
#    Origen     Auxiliar    Destino
#
#
# Paso 3: Mover disco 1 de destino a auxiliar
#
#      |           |           |
#      |           —           |
#    —————        ———          |
#    Origen     Auxiliar    Destino
#
#
# Paso 4: Mover disco 3 de origen a destino
#
#      |           |           |
#      |           —           |
#      |          ———        —————
#    Origen     Auxiliar    Destino
#
#
# Paso 5: Mover disco 1 de auxiliar a origen
#
#      |           |           |
#      |           |           |
#      —          ———        —————
#    Origen     Auxiliar    Destino
#
#
# Paso 6: Mover disco 2 de auxiliar a destino
#
#      |           |           |
#      |           |          ———
#      —           |         —————
#    Origen     Auxiliar    Destino
#
#
# Paso 7: Mover disco 1 de origen a destino
#
#      |           |           —
#      |           |          ———
#      |           |         —————
#    Origen     Auxiliar    Destino
#
#
# Una torre de Hanoi de 3 discos puede resolverse en 7 pasos.
# 7

# %%
TorresdeHanoi(5)
# Out:
#          —                   |                   |
#         ———                  |                   |
#        —————                 |                   |
#       ———————                |                   |
#      —————————               |                   |
#        Origen             Auxiliar            Destino
#
#
# Paso 1: Mover disco 1 de origen a destino
#
#          |                   |                   |
#         ———                  |                   |
#        —————                 |                   |
#       ———————                |                   |
#      —————————               |                   —
#        Origen             Auxiliar            Destino
#
#
# Paso 2: Mover disco 2 de origen a auxiliar
#
#          |                   |                   |
#          |                   |                   |
#        —————                 |                   |
#       ———————                |                   |
#      —————————              ———                  —
#        Origen             Auxiliar            Destino
#
#
# Paso 3: Mover disco 1 de destino a auxiliar
#
#          |                   |                   |
#          |                   |                   |
#        —————                 |                   |
#       ———————                —                   |
#      —————————              ———                  |
#        Origen             Auxiliar            Destino
#
#
# Paso 4: Mover disco 3 de origen a destino
#
#          |                   |                   |
#          |                   |                   |
#          |                   |                   |
#       ———————                —                   |
#      —————————              ———                —————
#        Origen             Auxiliar            Destino
#
#
# Paso 5: Mover disco 1 de auxiliar a origen
#
#          |                   |                   |
#          |                   |                   |
#          —                   |                   |
#       ———————                |                   |
#      —————————              ———                —————
#        Origen             Auxiliar            Destino
#
#
# Paso 6: Mover disco 2 de auxiliar a destino
#
#          |                   |                   |
#          |                   |                   |
#          —                   |                   |
#       ———————                |                  ———
#      —————————               |                 —————
#        Origen             Auxiliar            Destino
#
#
# Paso 7: Mover disco 1 de origen a destino
#
#          |                   |                   |
#          |                   |                   |
#          |                   |                   —
#       ———————                |                  ———
#      —————————               |                 —————
#        Origen             Auxiliar            Destino
#
#
# Paso 8: Mover disco 4 de origen a auxiliar
#
#          |                   |                   |
#          |                   |                   |
#          |                   |                   —
#          |                   |                  ———
#      —————————            ———————              —————
#        Origen             Auxiliar            Destino
#
#
# Paso 9: Mover disco 1 de destino a auxiliar
#
#          |                   |                   |
#          |                   |                   |
#          |                   |                   |
#          |                   —                  ———
#      —————————            ———————              —————
#        Origen             Auxiliar            Destino
#
#
# Paso 10: Mover disco 2 de destino a origen
#
#          |                   |                   |
#          |                   |                   |
#          |                   |                   |
#         ———                  —                   |
#      —————————            ———————              —————
#        Origen             Auxiliar            Destino
#
#
# Paso 11: Mover disco 1 de auxiliar a origen
#
#          |                   |                   |
#          |                   |                   |
#          —                   |                   |
#         ———                  |                   |
#      —————————            ———————              —————
#        Origen             Auxiliar            Destino
#
#
# Paso 12: Mover disco 3 de destino a auxiliar
#
#          |                   |                   |
#          |                   |                   |
#          —                   |                   |
#         ———                —————                 |
#      —————————            ———————                |
#        Origen             Auxiliar            Destino
#
#
# Paso 13: Mover disco 1 de origen a destino
#
#          |                   |                   |
#          |                   |                   |
#          |                   |                   |
#         ———                —————                 |
#      —————————            ———————                —
#        Origen             Auxiliar            Destino
#
#
# Paso 14: Mover disco 2 de origen a auxiliar
#
#          |                   |                   |
#          |                   |                   |
#          |                  ———                  |
#          |                 —————                 |
#      —————————            ———————                —
#        Origen             Auxiliar            Destino
#
#
# Paso 15: Mover disco 1 de destino a auxiliar
#
#          |                   |                   |
#          |                   —                   |
#          |                  ———                  |
#          |                 —————                 |
#      —————————            ———————                |
#        Origen             Auxiliar            Destino
#
#
# Paso 16: Mover disco 5 de origen a destino
#
#          |                   |                   |
#          |                   —                   |
#          |                  ———                  |
#          |                 —————                 |
#          |                ———————            —————————
#        Origen             Auxiliar            Destino
#
#
# Paso 17: Mover disco 1 de auxiliar a origen
#
#          |                   |                   |
#          |                   |                   |
#          |                  ———                  |
#          |                 —————                 |
#          —                ———————            —————————
#        Origen             Auxiliar            Destino
#
#
# Paso 18: Mover disco 2 de auxiliar a destino
#
#          |                   |                   |
#          |                   |                   |
#          |                   |                   |
#          |                 —————                ———
#          —                ———————            —————————
#        Origen             Auxiliar            Destino
#
#
# Paso 19: Mover disco 1 de origen a destino
#
#          |                   |                   |
#          |                   |                   |
#          |                   |                   —
#          |                 —————                ———
#          |                ———————            —————————
#        Origen             Auxiliar            Destino
#
#
# Paso 20: Mover disco 3 de auxiliar a origen
#
#          |                   |                   |
#          |                   |                   |
#          |                   |                   —
#          |                   |                  ———
#        —————              ———————            —————————
#        Origen             Auxiliar            Destino
#
#
# Paso 21: Mover disco 1 de destino a auxiliar
#
#          |                   |                   |
#          |                   |                   |
#          |                   |                   |
#          |                   —                  ———
#        —————              ———————            —————————
#        Origen             Auxiliar            Destino
#
#
# Paso 22: Mover disco 2 de destino a origen
#
#          |                   |                   |
#          |                   |                   |
#          |                   |                   |
#         ———                  —                   |
#        —————              ———————            —————————
#        Origen             Auxiliar            Destino
#
#
# Paso 23: Mover disco 1 de auxiliar a origen
#
#          |                   |                   |
#          |                   |                   |
#          —                   |                   |
#         ———                  |                   |
#        —————              ———————            —————————
#        Origen             Auxiliar            Destino
#
#
# Paso 24: Mover disco 4 de auxiliar a destino
#
#          |                   |                   |
#          |                   |                   |
#          —                   |                   |
#         ———                  |                ———————
#        —————                 |               —————————
#        Origen             Auxiliar            Destino
#
#
# Paso 25: Mover disco 1 de origen a destino
#
#          |                   |                   |
#          |                   |                   |
#          |                   |                   —
#         ———                  |                ———————
#        —————                 |               —————————
#        Origen             Auxiliar            Destino
#
#
# Paso 26: Mover disco 2 de origen a auxiliar
#
#          |                   |                   |
#          |                   |                   |
#          |                   |                   —
#          |                   |                ———————
#        —————                ———              —————————
#        Origen             Auxiliar            Destino
#
#
# Paso 27: Mover disco 1 de destino a auxiliar
#
#          |                   |                   |
#          |                   |                   |
#          |                   |                   |
#          |                   —                ———————
#        —————                ———              —————————
#        Origen             Auxiliar            Destino
#
#
# Paso 28: Mover disco 3 de origen a destino
#
#          |                   |                   |
#          |                   |                   |
#          |                   |                 —————
#          |                   —                ———————
#          |                  ———              —————————
#        Origen             Auxiliar            Destino
#
#
# Paso 29: Mover disco 1 de auxiliar a origen
#
#          |                   |                   |
#          |                   |                   |
#          |                   |                 —————
#          |                   |                ———————
#          —                  ———              —————————
#        Origen             Auxiliar            Destino
#
#
# Paso 30: Mover disco 2 de auxiliar a destino
#
#          |                   |                   |
#          |                   |                  ———
#          |                   |                 —————
#          |                   |                ———————
#          —                   |               —————————
#        Origen             Auxiliar            Destino
#
#
# Paso 31: Mover disco 1 de origen a destino
#
#          |                   |                   —
#          |                   |                  ———
#          |                   |                 —————
#          |                   |                ———————
#          |                   |               —————————
#        Origen             Auxiliar            Destino
#
#
# Una torre de Hanoi de 5 discos puede resolverse en 31 pasos.
# 31

# %%
TorresdeHanoi(7)
# Out:
#              —                           |                           |
#             ———                          |                           |
#            —————                         |                           |
#           ———————                        |                           |
#          —————————                       |                           |
#         ———————————                      |                           |
#        —————————————                     |                           |
#            Origen                     Auxiliar                    Destino
#
#
# Paso 1: Mover disco 1 de origen a destino
#
#              |                           |                           |
#             ———                          |                           |
#            —————                         |                           |
#           ———————                        |                           |
#          —————————                       |                           |
#         ———————————                      |                           |
#        —————————————                     |                           —
#            Origen                     Auxiliar                    Destino
#
#
# Paso 2: Mover disco 2 de origen a auxiliar
#
#              |                           |                           |
#              |                           |                           |
#            —————                         |                           |
#           ———————                        |                           |
#          —————————                       |                           |
#         ———————————                      |                           |
#        —————————————                    ———                          —
#            Origen                     Auxiliar                    Destino
#
#
# Paso 3: Mover disco 1 de destino a auxiliar
#
#              |                           |                           |
#              |                           |                           |
#            —————                         |                           |
#           ———————                        |                           |
#          —————————                       |                           |
#         ———————————                      —                           |
#        —————————————                    ———                          |
#            Origen                     Auxiliar                    Destino
#
#
# Paso 4: Mover disco 3 de origen a destino
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#           ———————                        |                           |
#          —————————                       |                           |
#         ———————————                      —                           |
#        —————————————                    ———                        —————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 5: Mover disco 1 de auxiliar a origen
#
#              |                           |                           |
#              |                           |                           |
#              —                           |                           |
#           ———————                        |                           |
#          —————————                       |                           |
#         ———————————                      |                           |
#        —————————————                    ———                        —————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 6: Mover disco 2 de auxiliar a destino
#
#              |                           |                           |
#              |                           |                           |
#              —                           |                           |
#           ———————                        |                           |
#          —————————                       |                           |
#         ———————————                      |                          ———
#        —————————————                     |                         —————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 7: Mover disco 1 de origen a destino
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#           ———————                        |                           |
#          —————————                       |                           —
#         ———————————                      |                          ———
#        —————————————                     |                         —————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 8: Mover disco 4 de origen a auxiliar
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#          —————————                       |                           —
#         ———————————                      |                          ———
#        —————————————                  ———————                      —————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 9: Mover disco 1 de destino a auxiliar
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#          —————————                       |                           |
#         ———————————                      —                          ———
#        —————————————                  ———————                      —————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 10: Mover disco 2 de destino a origen
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#             ———                          |                           |
#          —————————                       |                           |
#         ———————————                      —                           |
#        —————————————                  ———————                      —————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 11: Mover disco 1 de auxiliar a origen
#
#              |                           |                           |
#              |                           |                           |
#              —                           |                           |
#             ———                          |                           |
#          —————————                       |                           |
#         ———————————                      |                           |
#        —————————————                  ———————                      —————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 12: Mover disco 3 de destino a auxiliar
#
#              |                           |                           |
#              |                           |                           |
#              —                           |                           |
#             ———                          |                           |
#          —————————                       |                           |
#         ———————————                    —————                         |
#        —————————————                  ———————                        |
#            Origen                     Auxiliar                    Destino
#
#
# Paso 13: Mover disco 1 de origen a destino
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#             ———                          |                           |
#          —————————                       |                           |
#         ———————————                    —————                         |
#        —————————————                  ———————                        —
#            Origen                     Auxiliar                    Destino
#
#
# Paso 14: Mover disco 2 de origen a auxiliar
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#          —————————                      ———                          |
#         ———————————                    —————                         |
#        —————————————                  ———————                        —
#            Origen                     Auxiliar                    Destino
#
#
# Paso 15: Mover disco 1 de destino a auxiliar
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           —                           |
#          —————————                      ———                          |
#         ———————————                    —————                         |
#        —————————————                  ———————                        |
#            Origen                     Auxiliar                    Destino
#
#
# Paso 16: Mover disco 5 de origen a destino
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           —                           |
#              |                          ———                          |
#         ———————————                    —————                         |
#        —————————————                  ———————                    —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 17: Mover disco 1 de auxiliar a origen
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              —                          ———                          |
#         ———————————                    —————                         |
#        —————————————                  ———————                    —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 18: Mover disco 2 de auxiliar a destino
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              —                           |                           |
#         ———————————                    —————                        ———
#        —————————————                  ———————                    —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 19: Mover disco 1 de origen a destino
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           —
#         ———————————                    —————                        ———
#        —————————————                  ———————                    —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 20: Mover disco 3 de auxiliar a origen
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#            —————                         |                           —
#         ———————————                      |                          ———
#        —————————————                  ———————                    —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 21: Mover disco 1 de destino a auxiliar
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#            —————                         |                           |
#         ———————————                      —                          ———
#        —————————————                  ———————                    —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 22: Mover disco 2 de destino a origen
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#             ———                          |                           |
#            —————                         |                           |
#         ———————————                      —                           |
#        —————————————                  ———————                    —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 23: Mover disco 1 de auxiliar a origen
#
#              |                           |                           |
#              |                           |                           |
#              —                           |                           |
#             ———                          |                           |
#            —————                         |                           |
#         ———————————                      |                           |
#        —————————————                  ———————                    —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 24: Mover disco 4 de auxiliar a destino
#
#              |                           |                           |
#              |                           |                           |
#              —                           |                           |
#             ———                          |                           |
#            —————                         |                           |
#         ———————————                      |                        ———————
#        —————————————                     |                       —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 25: Mover disco 1 de origen a destino
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#             ———                          |                           |
#            —————                         |                           —
#         ———————————                      |                        ———————
#        —————————————                     |                       —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 26: Mover disco 2 de origen a auxiliar
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#            —————                         |                           —
#         ———————————                      |                        ———————
#        —————————————                    ———                      —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 27: Mover disco 1 de destino a auxiliar
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#            —————                         |                           |
#         ———————————                      —                        ———————
#        —————————————                    ———                      —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 28: Mover disco 3 de origen a destino
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                         —————
#         ———————————                      —                        ———————
#        —————————————                    ———                      —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 29: Mover disco 1 de auxiliar a origen
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              —                           |                         —————
#         ———————————                      |                        ———————
#        —————————————                    ———                      —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 30: Mover disco 2 de auxiliar a destino
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                          ———
#              —                           |                         —————
#         ———————————                      |                        ———————
#        —————————————                     |                       —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 31: Mover disco 1 de origen a destino
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           —
#              |                           |                          ———
#              |                           |                         —————
#         ———————————                      |                        ———————
#        —————————————                     |                       —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 32: Mover disco 6 de origen a auxiliar
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           —
#              |                           |                          ———
#              |                           |                         —————
#              |                           |                        ———————
#        —————————————                ———————————                  —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 33: Mover disco 1 de destino a auxiliar
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                          ———
#              |                           |                         —————
#              |                           —                        ———————
#        —————————————                ———————————                  —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 34: Mover disco 2 de destino a origen
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                         —————
#             ———                          —                        ———————
#        —————————————                ———————————                  —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 35: Mover disco 1 de auxiliar a origen
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              —                           |                         —————
#             ———                          |                        ———————
#        —————————————                ———————————                  —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 36: Mover disco 3 de destino a auxiliar
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              —                           |                           |
#             ———                        —————                      ———————
#        —————————————                ———————————                  —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 37: Mover disco 1 de origen a destino
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           —
#             ———                        —————                      ———————
#        —————————————                ———————————                  —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 38: Mover disco 2 de origen a auxiliar
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                          ———                          —
#              |                         —————                      ———————
#        —————————————                ———————————                  —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 39: Mover disco 1 de destino a auxiliar
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           —                           |
#              |                          ———                          |
#              |                         —————                      ———————
#        —————————————                ———————————                  —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 40: Mover disco 4 de destino a origen
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           —                           |
#              |                          ———                          |
#           ———————                      —————                         |
#        —————————————                ———————————                  —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 41: Mover disco 1 de auxiliar a origen
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              —                          ———                          |
#           ———————                      —————                         |
#        —————————————                ———————————                  —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 42: Mover disco 2 de auxiliar a destino
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              —                           |                           |
#           ———————                      —————                        ———
#        —————————————                ———————————                  —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 43: Mover disco 1 de origen a destino
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           —
#           ———————                      —————                        ———
#        —————————————                ———————————                  —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 44: Mover disco 3 de auxiliar a origen
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#            —————                         |                           —
#           ———————                        |                          ———
#        —————————————                ———————————                  —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 45: Mover disco 1 de destino a auxiliar
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#            —————                         |                           |
#           ———————                        —                          ———
#        —————————————                ———————————                  —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 46: Mover disco 2 de destino a origen
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#             ———                          |                           |
#            —————                         |                           |
#           ———————                        —                           |
#        —————————————                ———————————                  —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 47: Mover disco 1 de auxiliar a origen
#
#              |                           |                           |
#              |                           |                           |
#              —                           |                           |
#             ———                          |                           |
#            —————                         |                           |
#           ———————                        |                           |
#        —————————————                ———————————                  —————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 48: Mover disco 5 de destino a auxiliar
#
#              |                           |                           |
#              |                           |                           |
#              —                           |                           |
#             ———                          |                           |
#            —————                         |                           |
#           ———————                    —————————                       |
#        —————————————                ———————————                      |
#            Origen                     Auxiliar                    Destino
#
#
# Paso 49: Mover disco 1 de origen a destino
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#             ———                          |                           |
#            —————                         |                           |
#           ———————                    —————————                       |
#        —————————————                ———————————                      —
#            Origen                     Auxiliar                    Destino
#
#
# Paso 50: Mover disco 2 de origen a auxiliar
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#            —————                        ———                          |
#           ———————                    —————————                       |
#        —————————————                ———————————                      —
#            Origen                     Auxiliar                    Destino
#
#
# Paso 51: Mover disco 1 de destino a auxiliar
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           —                           |
#            —————                        ———                          |
#           ———————                    —————————                       |
#        —————————————                ———————————                      |
#            Origen                     Auxiliar                    Destino
#
#
# Paso 52: Mover disco 3 de origen a destino
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           —                           |
#              |                          ———                          |
#           ———————                    —————————                       |
#        —————————————                ———————————                    —————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 53: Mover disco 1 de auxiliar a origen
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              —                          ———                          |
#           ———————                    —————————                       |
#        —————————————                ———————————                    —————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 54: Mover disco 2 de auxiliar a destino
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              —                           |                           |
#           ———————                    —————————                      ———
#        —————————————                ———————————                    —————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 55: Mover disco 1 de origen a destino
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           —
#           ———————                    —————————                      ———
#        —————————————                ———————————                    —————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 56: Mover disco 4 de origen a auxiliar
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                        ———————                        —
#              |                       —————————                      ———
#        —————————————                ———————————                    —————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 57: Mover disco 1 de destino a auxiliar
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           —                           |
#              |                        ———————                        |
#              |                       —————————                      ———
#        —————————————                ———————————                    —————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 58: Mover disco 2 de destino a origen
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           —                           |
#              |                        ———————                        |
#             ———                      —————————                       |
#        —————————————                ———————————                    —————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 59: Mover disco 1 de auxiliar a origen
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              —                        ———————                        |
#             ———                      —————————                       |
#        —————————————                ———————————                    —————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 60: Mover disco 3 de destino a auxiliar
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                         —————                         |
#              —                        ———————                        |
#             ———                      —————————                       |
#        —————————————                ———————————                      |
#            Origen                     Auxiliar                    Destino
#
#
# Paso 61: Mover disco 1 de origen a destino
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                         —————                         |
#              |                        ———————                        |
#             ———                      —————————                       |
#        —————————————                ———————————                      —
#            Origen                     Auxiliar                    Destino
#
#
# Paso 62: Mover disco 2 de origen a auxiliar
#
#              |                           |                           |
#              |                           |                           |
#              |                          ———                          |
#              |                         —————                         |
#              |                        ———————                        |
#              |                       —————————                       |
#        —————————————                ———————————                      —
#            Origen                     Auxiliar                    Destino
#
#
# Paso 63: Mover disco 1 de destino a auxiliar
#
#              |                           |                           |
#              |                           —                           |
#              |                          ———                          |
#              |                         —————                         |
#              |                        ———————                        |
#              |                       —————————                       |
#        —————————————                ———————————                      |
#            Origen                     Auxiliar                    Destino
#
#
# Paso 64: Mover disco 7 de origen a destino
#
#              |                           |                           |
#              |                           —                           |
#              |                          ———                          |
#              |                         —————                         |
#              |                        ———————                        |
#              |                       —————————                       |
#              |                      ———————————                —————————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 65: Mover disco 1 de auxiliar a origen
#
#              |                           |                           |
#              |                           |                           |
#              |                          ———                          |
#              |                         —————                         |
#              |                        ———————                        |
#              |                       —————————                       |
#              —                      ———————————                —————————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 66: Mover disco 2 de auxiliar a destino
#
# ...
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                         —————
#             ———                          —                      ———————————
#          —————————                    ———————                  —————————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 107: Mover disco 1 de auxiliar a origen
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              —                           |                         —————
#             ———                          |                      ———————————
#          —————————                    ———————                  —————————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 108: Mover disco 3 de destino a auxiliar
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              —                           |                           |
#             ———                        —————                    ———————————
#          —————————                    ———————                  —————————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 109: Mover disco 1 de origen a destino
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           —
#             ———                        —————                    ———————————
#          —————————                    ———————                  —————————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 110: Mover disco 2 de origen a auxiliar
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                          ———                          —
#              |                         —————                    ———————————
#          —————————                    ———————                  —————————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 111: Mover disco 1 de destino a auxiliar
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           —                           |
#              |                          ———                          |
#              |                         —————                    ———————————
#          —————————                    ———————                  —————————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 112: Mover disco 5 de origen a destino
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           —                           |
#              |                          ———                      —————————
#              |                         —————                    ———————————
#              |                        ———————                  —————————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 113: Mover disco 1 de auxiliar a origen
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                          ———                      —————————
#              |                         —————                    ———————————
#              —                        ———————                  —————————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 114: Mover disco 2 de auxiliar a destino
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                          ———
#              |                           |                       —————————
#              |                         —————                    ———————————
#              —                        ———————                  —————————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 115: Mover disco 1 de origen a destino
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           —
#              |                           |                          ———
#              |                           |                       —————————
#              |                         —————                    ———————————
#              |                        ———————                  —————————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 116: Mover disco 3 de auxiliar a origen
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           —
#              |                           |                          ———
#              |                           |                       —————————
#              |                           |                      ———————————
#            —————                      ———————                  —————————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 117: Mover disco 1 de destino a auxiliar
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                          ———
#              |                           |                       —————————
#              |                           —                      ———————————
#            —————                      ———————                  —————————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 118: Mover disco 2 de destino a origen
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                       —————————
#             ———                          —                      ———————————
#            —————                      ———————                  —————————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 119: Mover disco 1 de auxiliar a origen
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              —                           |                       —————————
#             ———                          |                      ———————————
#            —————                      ———————                  —————————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 120: Mover disco 4 de auxiliar a destino
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                        ———————
#              —                           |                       —————————
#             ———                          |                      ———————————
#            —————                         |                     —————————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 121: Mover disco 1 de origen a destino
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           —
#              |                           |                        ———————
#              |                           |                       —————————
#             ———                          |                      ———————————
#            —————                         |                     —————————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 122: Mover disco 2 de origen a auxiliar
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           —
#              |                           |                        ———————
#              |                           |                       —————————
#              |                           |                      ———————————
#            —————                        ———                    —————————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 123: Mover disco 1 de destino a auxiliar
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                           |
#              |                           |                        ———————
#              |                           |                       —————————
#              |                           —                      ———————————
#            —————                        ———                    —————————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 124: Mover disco 3 de origen a destino
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                         —————
#              |                           |                        ———————
#              |                           |                       —————————
#              |                           —                      ———————————
#              |                          ———                    —————————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 125: Mover disco 1 de auxiliar a origen
#
#              |                           |                           |
#              |                           |                           |
#              |                           |                         —————
#              |                           |                        ———————
#              |                           |                       —————————
#              |                           |                      ———————————
#              —                          ———                    —————————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 126: Mover disco 2 de auxiliar a destino
#
#              |                           |                           |
#              |                           |                          ———
#              |                           |                         —————
#              |                           |                        ———————
#              |                           |                       —————————
#              |                           |                      ———————————
#              —                           |                     —————————————
#            Origen                     Auxiliar                    Destino
#
#
# Paso 127: Mover disco 1 de origen a destino
#
#              |                           |                           —
#              |                           |                          ———
#              |                           |                         —————
#              |                           |                        ———————
#              |                           |                       —————————
#              |                           |                      ———————————
#              |                           |                     —————————————
#            Origen                     Auxiliar                    Destino
#
#
# Una torre de Hanoi de 7 discos puede resolverse en 127 pasos.
# 127

# %%
TorresdeHanoi(12, False)
# Out:
# Paso 1: Mover disco 1 de origen a auxiliar
# Paso 2: Mover disco 2 de origen a destino
# Paso 3: Mover disco 1 de auxiliar a destino
# Paso 4: Mover disco 3 de origen a auxiliar
# Paso 5: Mover disco 1 de destino a origen
# Paso 6: Mover disco 2 de destino a auxiliar
# Paso 7: Mover disco 1 de origen a auxiliar
# Paso 8: Mover disco 4 de origen a destino
# Paso 9: Mover disco 1 de auxiliar a destino
# Paso 10: Mover disco 2 de auxiliar a origen
# Paso 11: Mover disco 1 de destino a origen
# Paso 12: Mover disco 3 de auxiliar a destino
# Paso 13: Mover disco 1 de origen a auxiliar
# Paso 14: Mover disco 2 de origen a destino
# Paso 15: Mover disco 1 de auxiliar a destino
# Paso 16: Mover disco 5 de origen a auxiliar
# Paso 17: Mover disco 1 de destino a origen
# Paso 18: Mover disco 2 de destino a auxiliar
# Paso 19: Mover disco 1 de origen a auxiliar
# Paso 20: Mover disco 3 de destino a origen
# Paso 21: Mover disco 1 de auxiliar a destino
# Paso 22: Mover disco 2 de auxiliar a origen
# Paso 23: Mover disco 1 de destino a origen
# Paso 24: Mover disco 4 de destino a auxiliar
# Paso 25: Mover disco 1 de origen a auxiliar
# Paso 26: Mover disco 2 de origen a destino
# Paso 27: Mover disco 1 de auxiliar a destino
# Paso 28: Mover disco 3 de origen a auxiliar
# Paso 29: Mover disco 1 de destino a origen
# Paso 30: Mover disco 2 de destino a auxiliar
# Paso 31: Mover disco 1 de origen a auxiliar
# Paso 32: Mover disco 6 de origen a destino
# Paso 33: Mover disco 1 de auxiliar a destino
# Paso 34: Mover disco 2 de auxiliar a origen
# Paso 35: Mover disco 1 de destino a origen
# Paso 36: Mover disco 3 de auxiliar a destino
# Paso 37: Mover disco 1 de origen a auxiliar
# Paso 38: Mover disco 2 de origen a destino
# Paso 39: Mover disco 1 de auxiliar a destino
# Paso 40: Mover disco 4 de auxiliar a origen
# Paso 41: Mover disco 1 de destino a origen
# Paso 42: Mover disco 2 de destino a auxiliar
# Paso 43: Mover disco 1 de origen a auxiliar
# Paso 44: Mover disco 3 de destino a origen
# Paso 45: Mover disco 1 de auxiliar a destino
# Paso 46: Mover disco 2 de auxiliar a origen
# Paso 47: Mover disco 1 de destino a origen
# Paso 48: Mover disco 5 de auxiliar a destino
# Paso 49: Mover disco 1 de origen a auxiliar
# Paso 50: Mover disco 2 de origen a destino
# Paso 51: Mover disco 1 de auxiliar a destino
# Paso 52: Mover disco 3 de origen a auxiliar
# Paso 53: Mover disco 1 de destino a origen
# Paso 54: Mover disco 2 de destino a auxiliar
# Paso 55: Mover disco 1 de origen a auxiliar
# Paso 56: Mover disco 4 de origen a destino
# Paso 57: Mover disco 1 de auxiliar a destino
# Paso 58: Mover disco 2 de auxiliar a origen
# Paso 59: Mover disco 1 de destino a origen
# Paso 60: Mover disco 3 de auxiliar a destino
# Paso 61: Mover disco 1 de origen a auxiliar
# Paso 62: Mover disco 2 de origen a destino
# Paso 63: Mover disco 1 de auxiliar a destino
# Paso 64: Mover disco 7 de origen a auxiliar
# Paso 65: Mover disco 1 de destino a origen
# Paso 66: Mover disco 2 de destino a auxiliar
# Paso 67: Mover disco 1 de origen a auxiliar
# Paso 68: Mover disco 3 de destino a origen
# Paso 69: Mover disco 1 de auxiliar a destino
# Paso 70: Mover disco 2 de auxiliar a origen
# Paso 71: Mover disco 1 de destino a origen
# Paso 72: Mover disco 4 de destino a auxiliar
# Paso 73: Mover disco 1 de origen a auxiliar
# Paso 74: Mover disco 2 de origen a destino
# Paso 75: Mover disco 1 de auxiliar a destino
# Paso 76: Mover disco 3 de origen a auxiliar
# Paso 77: Mover disco 1 de destino a origen
# Paso 78: Mover disco 2 de destino a auxiliar
# Paso 79: Mover disco 1 de origen a auxiliar
# Paso 80: Mover disco 5 de destino a origen
# Paso 81: Mover disco 1 de auxiliar a destino
# Paso 82: Mover disco 2 de auxiliar a origen
# Paso 83: Mover disco 1 de destino a origen
# Paso 84: Mover disco 3 de auxiliar a destino
# Paso 85: Mover disco 1 de origen a auxiliar
# Paso 86: Mover disco 2 de origen a destino
# Paso 87: Mover disco 1 de auxiliar a destino
# Paso 88: Mover disco 4 de auxiliar a origen
# Paso 89: Mover disco 1 de destino a origen
# Paso 90: Mover disco 2 de destino a auxiliar
# Paso 91: Mover disco 1 de origen a auxiliar
# Paso 92: Mover disco 3 de destino a origen
# Paso 93: Mover disco 1 de auxiliar a destino
# Paso 94: Mover disco 2 de auxiliar a origen
# Paso 95: Mover disco 1 de destino a origen
# Paso 96: Mover disco 6 de destino a auxiliar
# Paso 97: Mover disco 1 de origen a auxiliar
# Paso 98: Mover disco 2 de origen a destino
# Paso 99: Mover disco 1 de auxiliar a destino
# Paso 100: Mover disco 3 de origen a auxiliar
# Paso 101: Mover disco 1 de destino a origen
# Paso 102: Mover disco 2 de destino a auxiliar
# Paso 103: Mover disco 1 de origen a auxiliar
# Paso 104: Mover disco 4 de origen a destino
# Paso 105: Mover disco 1 de auxiliar a destino
# Paso 106: Mover disco 2 de auxiliar a origen
# Paso 107: Mover disco 1 de destino a origen
# Paso 108: Mover disco 3 de auxiliar a destino
# Paso 109: Mover disco 1 de origen a auxiliar
# Paso 110: Mover disco 2 de origen a destino
# Paso 111: Mover disco 1 de auxiliar a destino
# Paso 112: Mover disco 5 de origen a auxiliar
# Paso 113: Mover disco 1 de destino a origen
# Paso 114: Mover disco 2 de destino a auxiliar
# Paso 115: Mover disco 1 de origen a auxiliar
# Paso 116: Mover disco 3 de destino a origen
# Paso 117: Mover disco 1 de auxiliar a destino
# Paso 118: Mover disco 2 de auxiliar a origen
# Paso 119: Mover disco 1 de destino a origen
# Paso 120: Mover disco 4 de destino a auxiliar
# Paso 121: Mover disco 1 de origen a auxiliar
# Paso 122: Mover disco 2 de origen a destino
# Paso 123: Mover disco 1 de auxiliar a destino
# Paso 124: Mover disco 3 de origen a auxiliar
# Paso 125: Mover disco 1 de destino a origen
# Paso 126: Mover disco 2 de destino a auxiliar
# Paso 127: Mover disco 1 de origen a auxiliar
# Paso 128: Mover disco 8 de origen a destino
# Paso 129: Mover disco 1 de auxiliar a destino
# Paso 130: Mover disco 2 de auxiliar a origen
# Paso 131: Mover disco 1 de destino a origen
# Paso 132: Mover disco 3 de auxiliar a destino
# Paso 133: Mover disco 1 de origen a auxiliar
# Paso 134: Mover disco 2 de origen a destino
# Paso 135: Mover disco 1 de auxiliar a destino
# Paso 136: Mover disco 4 de auxiliar a origen
# Paso 137: Mover disco 1 de destino a origen
# Paso 138: Mover disco 2 de destino a auxiliar
# Paso 139: Mover disco 1 de origen a auxiliar
# Paso 140: Mover disco 3 de destino a origen
# Paso 141: Mover disco 1 de auxiliar a destino
# Paso 142: Mover disco 2 de auxiliar a origen
# Paso 143: Mover disco 1 de destino a origen
# Paso 144: Mover disco 5 de auxiliar a destino
# Paso 145: Mover disco 1 de origen a auxiliar
# Paso 146: Mover disco 2 de origen a destino
# Paso 147: Mover disco 1 de auxiliar a destino
# Paso 148: Mover disco 3 de origen a auxiliar
# Paso 149: Mover disco 1 de destino a origen
# Paso 150: Mover disco 2 de destino a auxiliar
# Paso 151: Mover disco 1 de origen a auxiliar
# Paso 152: Mover disco 4 de origen a destino
# Paso 153: Mover disco 1 de auxiliar a destino
# Paso 154: Mover disco 2 de auxiliar a origen
# Paso 155: Mover disco 1 de destino a origen
# Paso 156: Mover disco 3 de auxiliar a destino
# Paso 157: Mover disco 1 de origen a auxiliar
# Paso 158: Mover disco 2 de origen a destino
# Paso 159: Mover disco 1 de auxiliar a destino
# Paso 160: Mover disco 6 de auxiliar a origen
# Paso 161: Mover disco 1 de destino a origen
# Paso 162: Mover disco 2 de destino a auxiliar
# Paso 163: Mover disco 1 de origen a auxiliar
# Paso 164: Mover disco 3 de destino a origen
# Paso 165: Mover disco 1 de auxiliar a destino
# Paso 166: Mover disco 2 de auxiliar a origen
# Paso 167: Mover disco 1 de destino a origen
# Paso 168: Mover disco 4 de destino a auxiliar
# Paso 169: Mover disco 1 de origen a auxiliar
# Paso 170: Mover disco 2 de origen a destino
# Paso 171: Mover disco 1 de auxiliar a destino
# Paso 172: Mover disco 3 de origen a auxiliar
# Paso 173: Mover disco 1 de destino a origen
# Paso 174: Mover disco 2 de destino a auxiliar
# Paso 175: Mover disco 1 de origen a auxiliar
# Paso 176: Mover disco 5 de destino a origen
# Paso 177: Mover disco 1 de auxiliar a destino
# Paso 178: Mover disco 2 de auxiliar a origen
# Paso 179: Mover disco 1 de destino a origen
# Paso 180: Mover disco 3 de auxiliar a destino
# Paso 181: Mover disco 1 de origen a auxiliar
# Paso 182: Mover disco 2 de origen a destino
# Paso 183: Mover disco 1 de auxiliar a destino
# Paso 184: Mover disco 4 de auxiliar a origen
# Paso 185: Mover disco 1 de destino a origen
# Paso 186: Mover disco 2 de destino a auxiliar
# Paso 187: Mover disco 1 de origen a auxiliar
# Paso 188: Mover disco 3 de destino a origen
# Paso 189: Mover disco 1 de auxiliar a destino
# Paso 190: Mover disco 2 de auxiliar a origen
# Paso 191: Mover disco 1 de destino a origen
# Paso 192: Mover disco 7 de auxiliar a destino
# Paso 193: Mover disco 1 de origen a auxiliar
# Paso 194: Mover disco 2 de origen a destino
# Paso 195: Mover disco 1 de auxiliar a destino
# Paso 196: Mover disco 3 de origen a auxiliar
# Paso 197: Mover disco 1 de destino a origen
# Paso 198: Mover disco 2 de destino a auxiliar
# Paso 199: Mover disco 1 de origen a auxiliar
# Paso 200: Mover disco 4 de origen a destino
# Paso 201: Mover disco 1 de auxiliar a destino
# Paso 202: Mover disco 2 de auxiliar a origen
# Paso 203: Mover disco 1 de destino a origen
# Paso 204: Mover disco 3 de auxiliar a destino
# Paso 205: Mover disco 1 de origen a auxiliar
# Paso 206: Mover disco 2 de origen a destino
# Paso 207: Mover disco 1 de auxiliar a destino
# Paso 208: Mover disco 5 de origen a auxiliar
# Paso 209: Mover disco 1 de destino a origen
# Paso 210: Mover disco 2 de destino a auxiliar
# Paso 211: Mover disco 1 de origen a auxiliar
# Paso 212: Mover disco 3 de destino a origen
# Paso 213: Mover disco 1 de auxiliar a destino
# Paso 214: Mover disco 2 de auxiliar a origen
# Paso 215: Mover disco 1 de destino a origen
# Paso 216: Mover disco 4 de destino a auxiliar
# Paso 217: Mover disco 1 de origen a auxiliar
# Paso 218: Mover disco 2 de origen a destino
# Paso 219: Mover disco 1 de auxiliar a destino
# Paso 220: Mover disco 3 de origen a auxiliar
# Paso 221: Mover disco 1 de destino a origen
# Paso 222: Mover disco 2 de destino a auxiliar
# Paso 223: Mover disco 1 de origen a auxiliar
# Paso 224: Mover disco 6 de origen a destino
# Paso 225: Mover disco 1 de auxiliar a destino
# Paso 226: Mover disco 2 de auxiliar a origen
# Paso 227: Mover disco 1 de destino a origen
# Paso 228: Mover disco 3 de auxiliar a destino
# Paso 229: Mover disco 1 de origen a auxiliar
# Paso 230: Mover disco 2 de origen a destino
# Paso 231: Mover disco 1 de auxiliar a destino
# Paso 232: Mover disco 4 de auxiliar a origen
# Paso 233: Mover disco 1 de destino a origen
# Paso 234: Mover disco 2 de destino a auxiliar
# Paso 235: Mover disco 1 de origen a auxiliar
# Paso 236: Mover disco 3 de destino a origen
# Paso 237: Mover disco 1 de auxiliar a destino
# Paso 238: Mover disco 2 de auxiliar a origen
# Paso 239: Mover disco 1 de destino a origen
# Paso 240: Mover disco 5 de auxiliar a destino
# Paso 241: Mover disco 1 de origen a auxiliar
# Paso 242: Mover disco 2 de origen a destino
# Paso 243: Mover disco 1 de auxiliar a destino
# Paso 244: Mover disco 3 de origen a auxiliar
# Paso 245: Mover disco 1 de destino a origen
# Paso 246: Mover disco 2 de destino a auxiliar
# Paso 247: Mover disco 1 de origen a auxiliar
# Paso 248: Mover disco 4 de origen a destino
# Paso 249: Mover disco 1 de auxiliar a destino
# Paso 250: Mover disco 2 de auxiliar a origen
# Paso 251: Mover disco 1 de destino a origen
# Paso 252: Mover disco 3 de auxiliar a destino
# Paso 253: Mover disco 1 de origen a auxiliar
# Paso 254: Mover disco 2 de origen a destino
# Paso 255: Mover disco 1 de auxiliar a destino
# Paso 256: Mover disco 9 de origen a auxiliar
# Paso 257: Mover disco 1 de destino a origen
# Paso 258: Mover disco 2 de destino a auxiliar
# Paso 259: Mover disco 1 de origen a auxiliar
# Paso 260: Mover disco 3 de destino a origen
# Paso 261: Mover disco 1 de auxiliar a destino
# Paso 262: Mover disco 2 de auxiliar a origen
# Paso 263: Mover disco 1 de destino a origen
# Paso 264: Mover disco 4 de destino a auxiliar
# Paso 265: Mover disco 1 de origen a auxiliar
# Paso 266: Mover disco 2 de origen a destino
# Paso 267: Mover disco 1 de auxiliar a destino
# Paso 268: Mover disco 3 de origen a auxiliar
# Paso 269: Mover disco 1 de destino a origen
# Paso 270: Mover disco 2 de destino a auxiliar
# Paso 271: Mover disco 1 de origen a auxiliar
# Paso 272: Mover disco 5 de destino a origen
# Paso 273: Mover disco 1 de auxiliar a destino
# Paso 274: Mover disco 2 de auxiliar a origen
# Paso 275: Mover disco 1 de destino a origen
# Paso 276: Mover disco 3 de auxiliar a destino
# Paso 277: Mover disco 1 de origen a auxiliar
# Paso 278: Mover disco 2 de origen a destino
# Paso 279: Mover disco 1 de auxiliar a destino
# Paso 280: Mover disco 4 de auxiliar a origen
# Paso 281: Mover disco 1 de destino a origen
# Paso 282: Mover disco 2 de destino a auxiliar
# Paso 283: Mover disco 1 de origen a auxiliar
# Paso 284: Mover disco 3 de destino a origen
# Paso 285: Mover disco 1 de auxiliar a destino
# Paso 286: Mover disco 2 de auxiliar a origen
# Paso 287: Mover disco 1 de destino a origen
# Paso 288: Mover disco 6 de destino a auxiliar
# Paso 289: Mover disco 1 de origen a auxiliar
# Paso 290: Mover disco 2 de origen a destino
# Paso 291: Mover disco 1 de auxiliar a destino
# Paso 292: Mover disco 3 de origen a auxiliar
# Paso 293: Mover disco 1 de destino a origen
# Paso 294: Mover disco 2 de destino a auxiliar
# Paso 295: Mover disco 1 de origen a auxiliar
# Paso 296: Mover disco 4 de origen a destino
# Paso 297: Mover disco 1 de auxiliar a destino
# Paso 298: Mover disco 2 de auxiliar a origen
# Paso 299: Mover disco 1 de destino a origen
# Paso 300: Mover disco 3 de auxiliar a destino
# Paso 301: Mover disco 1 de origen a auxiliar
# Paso 302: Mover disco 2 de origen a destino
# Paso 303: Mover disco 1 de auxiliar a destino
# Paso 304: Mover disco 5 de origen a auxiliar
# Paso 305: Mover disco 1 de destino a origen
# Paso 306: Mover disco 2 de destino a auxiliar
# Paso 307: Mover disco 1 de origen a auxiliar
# Paso 308: Mover disco 3 de destino a origen
# Paso 309: Mover disco 1 de auxiliar a destino
# Paso 310: Mover disco 2 de auxiliar a origen
# Paso 311: Mover disco 1 de destino a origen
# Paso 312: Mover disco 4 de destino a auxiliar
# Paso 313: Mover disco 1 de origen a auxiliar
# Paso 314: Mover disco 2 de origen a destino
# Paso 315: Mover disco 1 de auxiliar a destino
# Paso 316: Mover disco 3 de origen a auxiliar
# Paso 317: Mover disco 1 de destino a origen
# Paso 318: Mover disco 2 de destino a auxiliar
# Paso 319: Mover disco 1 de origen a auxiliar
# Paso 320: Mover disco 7 de destino a origen
# Paso 321: Mover disco 1 de auxiliar a destino
# Paso 322: Mover disco 2 de auxiliar a origen
# Paso 323: Mover disco 1 de destino a origen
# Paso 324: Mover disco 3 de auxiliar a destino
# Paso 325: Mover disco 1 de origen a auxiliar
# Paso 326: Mover disco 2 de origen a destino
# Paso 327: Mover disco 1 de auxiliar a destino
# Paso 328: Mover disco 4 de auxiliar a origen
# Paso 329: Mover disco 1 de destino a origen
# Paso 330: Mover disco 2 de destino a auxiliar
# Paso 331: Mover disco 1 de origen a auxiliar
# Paso 332: Mover disco 3 de destino a origen
# Paso 333: Mover disco 1 de auxiliar a destino
# Paso 334: Mover disco 2 de auxiliar a origen
# Paso 335: Mover disco 1 de destino a origen
# Paso 336: Mover disco 5 de auxiliar a destino
# Paso 337: Mover disco 1 de origen a auxiliar
# Paso 338: Mover disco 2 de origen a destino
# Paso 339: Mover disco 1 de auxiliar a destino
# Paso 340: Mover disco 3 de origen a auxiliar
# Paso 341: Mover disco 1 de destino a origen
# Paso 342: Mover disco 2 de destino a auxiliar
# Paso 343: Mover disco 1 de origen a auxiliar
# Paso 344: Mover disco 4 de origen a destino
# Paso 345: Mover disco 1 de auxiliar a destino
# Paso 346: Mover disco 2 de auxiliar a origen
# Paso 347: Mover disco 1 de destino a origen
# Paso 348: Mover disco 3 de auxiliar a destino
# Paso 349: Mover disco 1 de origen a auxiliar
# Paso 350: Mover disco 2 de origen a destino
# Paso 351: Mover disco 1 de auxiliar a destino
# Paso 352: Mover disco 6 de auxiliar a origen
# Paso 353: Mover disco 1 de destino a origen
# Paso 354: Mover disco 2 de destino a auxiliar
# Paso 355: Mover disco 1 de origen a auxiliar
# Paso 356: Mover disco 3 de destino a origen
# Paso 357: Mover disco 1 de auxiliar a destino
# Paso 358: Mover disco 2 de auxiliar a origen
# Paso 359: Mover disco 1 de destino a origen
# Paso 360: Mover disco 4 de destino a auxiliar
# Paso 361: Mover disco 1 de origen a auxiliar
# Paso 362: Mover disco 2 de origen a destino
# Paso 363: Mover disco 1 de auxiliar a destino
# Paso 364: Mover disco 3 de origen a auxiliar
# Paso 365: Mover disco 1 de destino a origen
# Paso 366: Mover disco 2 de destino a auxiliar
# Paso 367: Mover disco 1 de origen a auxiliar
# Paso 368: Mover disco 5 de destino a origen
# Paso 369: Mover disco 1 de auxiliar a destino
# Paso 370: Mover disco 2 de auxiliar a origen
# Paso 371: Mover disco 1 de destino a origen
# Paso 372: Mover disco 3 de auxiliar a destino
# Paso 373: Mover disco 1 de origen a auxiliar
# Paso 374: Mover disco 2 de origen a destino
# Paso 375: Mover disco 1 de auxiliar a destino
# Paso 376: Mover disco 4 de auxiliar a origen
# Paso 377: Mover disco 1 de destino a origen
# Paso 378: Mover disco 2 de destino a auxiliar
# Paso 379: Mover disco 1 de origen a auxiliar
# Paso 380: Mover disco 3 de destino a origen
# Paso 381: Mover disco 1 de auxiliar a destino
# Paso 382: Mover disco 2 de auxiliar a origen
# Paso 383: Mover disco 1 de destino a origen
# Paso 384: Mover disco 8 de destino a auxiliar
# Paso 385: Mover disco 1 de origen a auxiliar
# Paso 386: Mover disco 2 de origen a destino
# Paso 387: Mover disco 1 de auxiliar a destino
# Paso 388: Mover disco 3 de origen a auxiliar
# Paso 389: Mover disco 1 de destino a origen
# Paso 390: Mover disco 2 de destino a auxiliar
# Paso 391: Mover disco 1 de origen a auxiliar
# Paso 392: Mover disco 4 de origen a destino
# Paso 393: Mover disco 1 de auxiliar a destino
# Paso 394: Mover disco 2 de auxiliar a origen
# Paso 395: Mover disco 1 de destino a origen
# Paso 396: Mover disco 3 de auxiliar a destino
# Paso 397: Mover disco 1 de origen a auxiliar
# Paso 398: Mover disco 2 de origen a destino
# Paso 399: Mover disco 1 de auxiliar a destino
# Paso 400: Mover disco 5 de origen a auxiliar
# Paso 401: Mover disco 1 de destino a origen
# Paso 402: Mover disco 2 de destino a auxiliar
# Paso 403: Mover disco 1 de origen a auxiliar
# Paso 404: Mover disco 3 de destino a origen
# Paso 405: Mover disco 1 de auxiliar a destino
# Paso 406: Mover disco 2 de auxiliar a origen
# Paso 407: Mover disco 1 de destino a origen
# Paso 408: Mover disco 4 de destino a auxiliar
# Paso 409: Mover disco 1 de origen a auxiliar
# Paso 410: Mover disco 2 de origen a destino
# Paso 411: Mover disco 1 de auxiliar a destino
# Paso 412: Mover disco 3 de origen a auxiliar
# Paso 413: Mover disco 1 de destino a origen
# Paso 414: Mover disco 2 de destino a auxiliar
# Paso 415: Mover disco 1 de origen a auxiliar
# Paso 416: Mover disco 6 de origen a destino
# Paso 417: Mover disco 1 de auxiliar a destino
# Paso 418: Mover disco 2 de auxiliar a origen
# Paso 419: Mover disco 1 de destino a origen
# Paso 420: Mover disco 3 de auxiliar a destino
# Paso 421: Mover disco 1 de origen a auxiliar
# Paso 422: Mover disco 2 de origen a destino
# Paso 423: Mover disco 1 de auxiliar a destino
# Paso 424: Mover disco 4 de auxiliar a origen
# Paso 425: Mover disco 1 de destino a origen
# Paso 426: Mover disco 2 de destino a auxiliar
# Paso 427: Mover disco 1 de origen a auxiliar
# Paso 428: Mover disco 3 de destino a origen
# Paso 429: Mover disco 1 de auxiliar a destino
# Paso 430: Mover disco 2 de auxiliar a origen
# Paso 431: Mover disco 1 de destino a origen
# Paso 432: Mover disco 5 de auxiliar a destino
# Paso 433: Mover disco 1 de origen a auxiliar
# Paso 434: Mover disco 2 de origen a destino
# Paso 435: Mover disco 1 de auxiliar a destino
# Paso 436: Mover disco 3 de origen a auxiliar
# Paso 437: Mover disco 1 de destino a origen
# Paso 438: Mover disco 2 de destino a auxiliar
# Paso 439: Mover disco 1 de origen a auxiliar
# Paso 440: Mover disco 4 de origen a destino
# Paso 441: Mover disco 1 de auxiliar a destino
# Paso 442: Mover disco 2 de auxiliar a origen
# Paso 443: Mover disco 1 de destino a origen
# Paso 444: Mover disco 3 de auxiliar a destino
# Paso 445: Mover disco 1 de origen a auxiliar
# Paso 446: Mover disco 2 de origen a destino
# Paso 447: Mover disco 1 de auxiliar a destino
# Paso 448: Mover disco 7 de origen a auxiliar
# Paso 449: Mover disco 1 de destino a origen
# Paso 450: Mover disco 2 de destino a auxiliar
# Paso 451: Mover disco 1 de origen a auxiliar
# Paso 452: Mover disco 3 de destino a origen
# Paso 453: Mover disco 1 de auxiliar a destino
# Paso 454: Mover disco 2 de auxiliar a origen
# Paso 455: Mover disco 1 de destino a origen
# Paso 456: Mover disco 4 de destino a auxiliar
# Paso 457: Mover disco 1 de origen a auxiliar
# Paso 458: Mover disco 2 de origen a destino
# Paso 459: Mover disco 1 de auxiliar a destino
# Paso 460: Mover disco 3 de origen a auxiliar
# Paso 461: Mover disco 1 de destino a origen
# Paso 462: Mover disco 2 de destino a auxiliar
# Paso 463: Mover disco 1 de origen a auxiliar
# Paso 464: Mover disco 5 de destino a origen
# Paso 465: Mover disco 1 de auxiliar a destino
# Paso 466: Mover disco 2 de auxiliar a origen
# Paso 467: Mover disco 1 de destino a origen
# Paso 468: Mover disco 3 de auxiliar a destino
# Paso 469: Mover disco 1 de origen a auxiliar
# Paso 470: Mover disco 2 de origen a destino
# Paso 471: Mover disco 1 de auxiliar a destino
# Paso 472: Mover disco 4 de auxiliar a origen
# Paso 473: Mover disco 1 de destino a origen
# Paso 474: Mover disco 2 de destino a auxiliar
# Paso 475: Mover disco 1 de origen a auxiliar
# Paso 476: Mover disco 3 de destino a origen
# Paso 477: Mover disco 1 de auxiliar a destino
# Paso 478: Mover disco 2 de auxiliar a origen
# Paso 479: Mover disco 1 de destino a origen
# Paso 480: Mover disco 6 de destino a auxiliar
# Paso 481: Mover disco 1 de origen a auxiliar
# Paso 482: Mover disco 2 de origen a destino
# Paso 483: Mover disco 1 de auxiliar a destino
# Paso 484: Mover disco 3 de origen a auxiliar
# Paso 485: Mover disco 1 de destino a origen
# Paso 486: Mover disco 2 de destino a auxiliar
# Paso 487: Mover disco 1 de origen a auxiliar
# Paso 488: Mover disco 4 de origen a destino
# Paso 489: Mover disco 1 de auxiliar a destino
# Paso 490: Mover disco 2 de auxiliar a origen
# Paso 491: Mover disco 1 de destino a origen
# Paso 492: Mover disco 3 de auxiliar a destino
# Paso 493: Mover disco 1 de origen a auxiliar
# Paso 494: Mover disco 2 de origen a destino
# Paso 495: Mover disco 1 de auxiliar a destino
# Paso 496: Mover disco 5 de origen a auxiliar
# Paso 497: Mover disco 1 de destino a origen
# Paso 498: Mover disco 2 de destino a auxiliar
# Paso 499: Mover disco 1 de origen a auxiliar
# Paso 500: Mover disco 3 de destino a origen
# Paso 501: Mover disco 1 de auxiliar a destino
# Paso 502: Mover disco 2 de auxiliar a origen
# Paso 503: Mover disco 1 de destino a origen
# Paso 504: Mover disco 4 de destino a auxiliar
# Paso 505: Mover disco 1 de origen a auxiliar
# Paso 506: Mover disco 2 de origen a destino
# Paso 507: Mover disco 1 de auxiliar a destino
# Paso 508: Mover disco 3 de origen a auxiliar
# Paso 509: Mover disco 1 de destino a origen
# Paso 510: Mover disco 2 de destino a auxiliar
# Paso 511: Mover disco 1 de origen a auxiliar
# Paso 512: Mover disco 10 de origen a destino
# Paso 513: Mover disco 1 de auxiliar a destino
# Paso 514: Mover disco 2 de auxiliar a origen
# Paso 515: Mover disco 1 de destino a origen
# Paso 516: Mover disco 3 de auxiliar a destino
# Paso 517: Mover disco 1 de origen a auxiliar
# Paso 518: Mover disco 2 de origen a destino
# Paso 519: Mover disco 1 de auxiliar a destino
# Paso 520: Mover disco 4 de auxiliar a origen
# Paso 521: Mover disco 1 de destino a origen
# Paso 522: Mover disco 2 de destino a auxiliar
# Paso 523: Mover disco 1 de origen a auxiliar
# Paso 524: Mover disco 3 de destino a origen
# Paso 525: Mover disco 1 de auxiliar a destino
# Paso 526: Mover disco 2 de auxiliar a origen
# Paso 527: Mover disco 1 de destino a origen
# Paso 528: Mover disco 5 de auxiliar a destino
# Paso 529: Mover disco 1 de origen a auxiliar
# Paso 530: Mover disco 2 de origen a destino
# Paso 531: Mover disco 1 de auxiliar a destino
# Paso 532: Mover disco 3 de origen a auxiliar
# Paso 533: Mover disco 1 de destino a origen
# Paso 534: Mover disco 2 de destino a auxiliar
# Paso 535: Mover disco 1 de origen a auxiliar
# Paso 536: Mover disco 4 de origen a destino
# Paso 537: Mover disco 1 de auxiliar a destino
# Paso 538: Mover disco 2 de auxiliar a origen
# Paso 539: Mover disco 1 de destino a origen
# Paso 540: Mover disco 3 de auxiliar a destino
# Paso 541: Mover disco 1 de origen a auxiliar
# Paso 542: Mover disco 2 de origen a destino
# Paso 543: Mover disco 1 de auxiliar a destino
# Paso 544: Mover disco 6 de auxiliar a origen
# Paso 545: Mover disco 1 de destino a origen
# Paso 546: Mover disco 2 de destino a auxiliar
# Paso 547: Mover disco 1 de origen a auxiliar
# Paso 548: Mover disco 3 de destino a origen
# Paso 549: Mover disco 1 de auxiliar a destino
# Paso 550: Mover disco 2 de auxiliar a origen
# Paso 551: Mover disco 1 de destino a origen
# Paso 552: Mover disco 4 de destino a auxiliar
# Paso 553: Mover disco 1 de origen a auxiliar
# Paso 554: Mover disco 2 de origen a destino
# Paso 555: Mover disco 1 de auxiliar a destino
# Paso 556: Mover disco 3 de origen a auxiliar
# Paso 557: Mover disco 1 de destino a origen
# Paso 558: Mover disco 2 de destino a auxiliar
# Paso 559: Mover disco 1 de origen a auxiliar
# Paso 560: Mover disco 5 de destino a origen
# Paso 561: Mover disco 1 de auxiliar a destino
# Paso 562: Mover disco 2 de auxiliar a origen
# Paso 563: Mover disco 1 de destino a origen
# Paso 564: Mover disco 3 de auxiliar a destino
# Paso 565: Mover disco 1 de origen a auxiliar
# Paso 566: Mover disco 2 de origen a destino
# Paso 567: Mover disco 1 de auxiliar a destino
# Paso 568: Mover disco 4 de auxiliar a origen
# Paso 569: Mover disco 1 de destino a origen
# Paso 570: Mover disco 2 de destino a auxiliar
# Paso 571: Mover disco 1 de origen a auxiliar
# Paso 572: Mover disco 3 de destino a origen
# Paso 573: Mover disco 1 de auxiliar a destino
# Paso 574: Mover disco 2 de auxiliar a origen
# Paso 575: Mover disco 1 de destino a origen
# Paso 576: Mover disco 7 de auxiliar a destino
# Paso 577: Mover disco 1 de origen a auxiliar
# Paso 578: Mover disco 2 de origen a destino
# Paso 579: Mover disco 1 de auxiliar a destino
# Paso 580: Mover disco 3 de origen a auxiliar
# Paso 581: Mover disco 1 de destino a origen
# Paso 582: Mover disco 2 de destino a auxiliar
# Paso 583: Mover disco 1 de origen a auxiliar
# Paso 584: Mover disco 4 de origen a destino
# Paso 585: Mover disco 1 de auxiliar a destino
# Paso 586: Mover disco 2 de auxiliar a origen
# Paso 587: Mover disco 1 de destino a origen
# Paso 588: Mover disco 3 de auxiliar a destino
# Paso 589: Mover disco 1 de origen a auxiliar
# Paso 590: Mover disco 2 de origen a destino
# Paso 591: Mover disco 1 de auxiliar a destino
# Paso 592: Mover disco 5 de origen a auxiliar
# Paso 593: Mover disco 1 de destino a origen
# Paso 594: Mover disco 2 de destino a auxiliar
# Paso 595: Mover disco 1 de origen a auxiliar
# Paso 596: Mover disco 3 de destino a origen
# Paso 597: Mover disco 1 de auxiliar a destino
# Paso 598: Mover disco 2 de auxiliar a origen
# Paso 599: Mover disco 1 de destino a origen
# Paso 600: Mover disco 4 de destino a auxiliar
# Paso 601: Mover disco 1 de origen a auxiliar
# Paso 602: Mover disco 2 de origen a destino
# Paso 603: Mover disco 1 de auxiliar a destino
# Paso 604: Mover disco 3 de origen a auxiliar
# Paso 605: Mover disco 1 de destino a origen
# Paso 606: Mover disco 2 de destino a auxiliar
# Paso 607: Mover disco 1 de origen a auxiliar
# Paso 608: Mover disco 6 de origen a destino
# Paso 609: Mover disco 1 de auxiliar a destino
# Paso 610: Mover disco 2 de auxiliar a origen
# Paso 611: Mover disco 1 de destino a origen
# Paso 612: Mover disco 3 de auxiliar a destino
# Paso 613: Mover disco 1 de origen a auxiliar
# Paso 614: Mover disco 2 de origen a destino
# Paso 615: Mover disco 1 de auxiliar a destino
# Paso 616: Mover disco 4 de auxiliar a origen
# Paso 617: Mover disco 1 de destino a origen
# Paso 618: Mover disco 2 de destino a auxiliar
# Paso 619: Mover disco 1 de origen a auxiliar
# Paso 620: Mover disco 3 de destino a origen
# Paso 621: Mover disco 1 de auxiliar a destino
# Paso 622: Mover disco 2 de auxiliar a origen
# Paso 623: Mover disco 1 de destino a origen
# Paso 624: Mover disco 5 de auxiliar a destino
# Paso 625: Mover disco 1 de origen a auxiliar
# Paso 626: Mover disco 2 de origen a destino
# Paso 627: Mover disco 1 de auxiliar a destino
# Paso 628: Mover disco 3 de origen a auxiliar
# Paso 629: Mover disco 1 de destino a origen
# Paso 630: Mover disco 2 de destino a auxiliar
# Paso 631: Mover disco 1 de origen a auxiliar
# Paso 632: Mover disco 4 de origen a destino
# Paso 633: Mover disco 1 de auxiliar a destino
# Paso 634: Mover disco 2 de auxiliar a origen
# Paso 635: Mover disco 1 de destino a origen
# Paso 636: Mover disco 3 de auxiliar a destino
# Paso 637: Mover disco 1 de origen a auxiliar
# Paso 638: Mover disco 2 de origen a destino
# Paso 639: Mover disco 1 de auxiliar a destino
# Paso 640: Mover disco 8 de auxiliar a origen
# Paso 641: Mover disco 1 de destino a origen
# Paso 642: Mover disco 2 de destino a auxiliar
# Paso 643: Mover disco 1 de origen a auxiliar
# Paso 644: Mover disco 3 de destino a origen
# Paso 645: Mover disco 1 de auxiliar a destino
# Paso 646: Mover disco 2 de auxiliar a origen
# Paso 647: Mover disco 1 de destino a origen
# Paso 648: Mover disco 4 de destino a auxiliar
# Paso 649: Mover disco 1 de origen a auxiliar
# Paso 650: Mover disco 2 de origen a destino
# Paso 651: Mover disco 1 de auxiliar a destino
# Paso 652: Mover disco 3 de origen a auxiliar
# Paso 653: Mover disco 1 de destino a origen
# Paso 654: Mover disco 2 de destino a auxiliar
# Paso 655: Mover disco 1 de origen a auxiliar
# Paso 656: Mover disco 5 de destino a origen
# Paso 657: Mover disco 1 de auxiliar a destino
# Paso 658: Mover disco 2 de auxiliar a origen
# Paso 659: Mover disco 1 de destino a origen
# Paso 660: Mover disco 3 de auxiliar a destino
# Paso 661: Mover disco 1 de origen a auxiliar
# Paso 662: Mover disco 2 de origen a destino
# Paso 663: Mover disco 1 de auxiliar a destino
# Paso 664: Mover disco 4 de auxiliar a origen
# Paso 665: Mover disco 1 de destino a origen
# Paso 666: Mover disco 2 de destino a auxiliar
# Paso 667: Mover disco 1 de origen a auxiliar
# Paso 668: Mover disco 3 de destino a origen
# Paso 669: Mover disco 1 de auxiliar a destino
# Paso 670: Mover disco 2 de auxiliar a origen
# Paso 671: Mover disco 1 de destino a origen
# Paso 672: Mover disco 6 de destino a auxiliar
# Paso 673: Mover disco 1 de origen a auxiliar
# Paso 674: Mover disco 2 de origen a destino
# Paso 675: Mover disco 1 de auxiliar a destino
# Paso 676: Mover disco 3 de origen a auxiliar
# Paso 677: Mover disco 1 de destino a origen
# Paso 678: Mover disco 2 de destino a auxiliar
# Paso 679: Mover disco 1 de origen a auxiliar
# Paso 680: Mover disco 4 de origen a destino
# Paso 681: Mover disco 1 de auxiliar a destino
# Paso 682: Mover disco 2 de auxiliar a origen
# Paso 683: Mover disco 1 de destino a origen
# Paso 684: Mover disco 3 de auxiliar a destino
# Paso 685: Mover disco 1 de origen a auxiliar
# Paso 686: Mover disco 2 de origen a destino
# Paso 687: Mover disco 1 de auxiliar a destino
# Paso 688: Mover disco 5 de origen a auxiliar
# Paso 689: Mover disco 1 de destino a origen
# Paso 690: Mover disco 2 de destino a auxiliar
# Paso 691: Mover disco 1 de origen a auxiliar
# Paso 692: Mover disco 3 de destino a origen
# Paso 693: Mover disco 1 de auxiliar a destino
# Paso 694: Mover disco 2 de auxiliar a origen
# Paso 695: Mover disco 1 de destino a origen
# Paso 696: Mover disco 4 de destino a auxiliar
# Paso 697: Mover disco 1 de origen a auxiliar
# Paso 698: Mover disco 2 de origen a destino
# Paso 699: Mover disco 1 de auxiliar a destino
# Paso 700: Mover disco 3 de origen a auxiliar
# Paso 701: Mover disco 1 de destino a origen
# Paso 702: Mover disco 2 de destino a auxiliar
# Paso 703: Mover disco 1 de origen a auxiliar
# Paso 704: Mover disco 7 de destino a origen
# Paso 705: Mover disco 1 de auxiliar a destino
# Paso 706: Mover disco 2 de auxiliar a origen
# Paso 707: Mover disco 1 de destino a origen
# Paso 708: Mover disco 3 de auxiliar a destino
# Paso 709: Mover disco 1 de origen a auxiliar
# Paso 710: Mover disco 2 de origen a destino
# Paso 711: Mover disco 1 de auxiliar a destino
# Paso 712: Mover disco 4 de auxiliar a origen
# Paso 713: Mover disco 1 de destino a origen
# Paso 714: Mover disco 2 de destino a auxiliar
# Paso 715: Mover disco 1 de origen a auxiliar
# Paso 716: Mover disco 3 de destino a origen
# Paso 717: Mover disco 1 de auxiliar a destino
# Paso 718: Mover disco 2 de auxiliar a origen
# Paso 719: Mover disco 1 de destino a origen
# Paso 720: Mover disco 5 de auxiliar a destino
# Paso 721: Mover disco 1 de origen a auxiliar
# Paso 722: Mover disco 2 de origen a destino
# Paso 723: Mover disco 1 de auxiliar a destino
# Paso 724: Mover disco 3 de origen a auxiliar
# Paso 725: Mover disco 1 de destino a origen
# Paso 726: Mover disco 2 de destino a auxiliar
# Paso 727: Mover disco 1 de origen a auxiliar
# Paso 728: Mover disco 4 de origen a destino
# Paso 729: Mover disco 1 de auxiliar a destino
# Paso 730: Mover disco 2 de auxiliar a origen
# Paso 731: Mover disco 1 de destino a origen
# Paso 732: Mover disco 3 de auxiliar a destino
# Paso 733: Mover disco 1 de origen a auxiliar
# Paso 734: Mover disco 2 de origen a destino
# Paso 735: Mover disco 1 de auxiliar a destino
# Paso 736: Mover disco 6 de auxiliar a origen
# Paso 737: Mover disco 1 de destino a origen
# Paso 738: Mover disco 2 de destino a auxiliar
# Paso 739: Mover disco 1 de origen a auxiliar
# Paso 740: Mover disco 3 de destino a origen
# Paso 741: Mover disco 1 de auxiliar a destino
# Paso 742: Mover disco 2 de auxiliar a origen
# Paso 743: Mover disco 1 de destino a origen
# Paso 744: Mover disco 4 de destino a auxiliar
# Paso 745: Mover disco 1 de origen a auxiliar
# Paso 746: Mover disco 2 de origen a destino
# Paso 747: Mover disco 1 de auxiliar a destino
# Paso 748: Mover disco 3 de origen a auxiliar
# Paso 749: Mover disco 1 de destino a origen
# Paso 750: Mover disco 2 de destino a auxiliar
# Paso 751: Mover disco 1 de origen a auxiliar
# Paso 752: Mover disco 5 de destino a origen
# Paso 753: Mover disco 1 de auxiliar a destino
# Paso 754: Mover disco 2 de auxiliar a origen
# Paso 755: Mover disco 1 de destino a origen
# Paso 756: Mover disco 3 de auxiliar a destino
# Paso 757: Mover disco 1 de origen a auxiliar
# Paso 758: Mover disco 2 de origen a destino
# Paso 759: Mover disco 1 de auxiliar a destino
# Paso 760: Mover disco 4 de auxiliar a origen
# Paso 761: Mover disco 1 de destino a origen
# Paso 762: Mover disco 2 de destino a auxiliar
# Paso 763: Mover disco 1 de origen a auxiliar
# Paso 764: Mover disco 3 de destino a origen
# Paso 765: Mover disco 1 de auxiliar a destino
# Paso 766: Mover disco 2 de auxiliar a origen
# Paso 767: Mover disco 1 de destino a origen
# Paso 768: Mover disco 9 de auxiliar a destino
# Paso 769: Mover disco 1 de origen a auxiliar
# Paso 770: Mover disco 2 de origen a destino
# Paso 771: Mover disco 1 de auxiliar a destino
# Paso 772: Mover disco 3 de origen a auxiliar
# Paso 773: Mover disco 1 de destino a origen
# Paso 774: Mover disco 2 de destino a auxiliar
# Paso 775: Mover disco 1 de origen a auxiliar
# Paso 776: Mover disco 4 de origen a destino
# Paso 777: Mover disco 1 de auxiliar a destino
# Paso 778: Mover disco 2 de auxiliar a origen
# Paso 779: Mover disco 1 de destino a origen
# Paso 780: Mover disco 3 de auxiliar a destino
# Paso 781: Mover disco 1 de origen a auxiliar
# Paso 782: Mover disco 2 de origen a destino
# Paso 783: Mover disco 1 de auxiliar a destino
# Paso 784: Mover disco 5 de origen a auxiliar
# Paso 785: Mover disco 1 de destino a origen
# Paso 786: Mover disco 2 de destino a auxiliar
# Paso 787: Mover disco 1 de origen a auxiliar
# Paso 788: Mover disco 3 de destino a origen
# Paso 789: Mover disco 1 de auxiliar a destino
# Paso 790: Mover disco 2 de auxiliar a origen
# Paso 791: Mover disco 1 de destino a origen
# Paso 792: Mover disco 4 de destino a auxiliar
# Paso 793: Mover disco 1 de origen a auxiliar
# Paso 794: Mover disco 2 de origen a destino
# Paso 795: Mover disco 1 de auxiliar a destino
# Paso 796: Mover disco 3 de origen a auxiliar
# Paso 797: Mover disco 1 de destino a origen
# Paso 798: Mover disco 2 de destino a auxiliar
# Paso 799: Mover disco 1 de origen a auxiliar
# Paso 800: Mover disco 6 de origen a destino
# Paso 801: Mover disco 1 de auxiliar a destino
# Paso 802: Mover disco 2 de auxiliar a origen
# Paso 803: Mover disco 1 de destino a origen
# Paso 804: Mover disco 3 de auxiliar a destino
# Paso 805: Mover disco 1 de origen a auxiliar
# Paso 806: Mover disco 2 de origen a destino
# Paso 807: Mover disco 1 de auxiliar a destino
# Paso 808: Mover disco 4 de auxiliar a origen
# Paso 809: Mover disco 1 de destino a origen
# Paso 810: Mover disco 2 de destino a auxiliar
# Paso 811: Mover disco 1 de origen a auxiliar
# Paso 812: Mover disco 3 de destino a origen
# Paso 813: Mover disco 1 de auxiliar a destino
# Paso 814: Mover disco 2 de auxiliar a origen
# Paso 815: Mover disco 1 de destino a origen
# Paso 816: Mover disco 5 de auxiliar a destino
# Paso 817: Mover disco 1 de origen a auxiliar
# Paso 818: Mover disco 2 de origen a destino
# Paso 819: Mover disco 1 de auxiliar a destino
# Paso 820: Mover disco 3 de origen a auxiliar
# Paso 821: Mover disco 1 de destino a origen
# Paso 822: Mover disco 2 de destino a auxiliar
# Paso 823: Mover disco 1 de origen a auxiliar
# Paso 824: Mover disco 4 de origen a destino
# Paso 825: Mover disco 1 de auxiliar a destino
# Paso 826: Mover disco 2 de auxiliar a origen
# Paso 827: Mover disco 1 de destino a origen
# Paso 828: Mover disco 3 de auxiliar a destino
# Paso 829: Mover disco 1 de origen a auxiliar
# Paso 830: Mover disco 2 de origen a destino
# Paso 831: Mover disco 1 de auxiliar a destino
# Paso 832: Mover disco 7 de origen a auxiliar
# Paso 833: Mover disco 1 de destino a origen
# Paso 834: Mover disco 2 de destino a auxiliar
# Paso 835: Mover disco 1 de origen a auxiliar
# Paso 836: Mover disco 3 de destino a origen
# Paso 837: Mover disco 1 de auxiliar a destino
# Paso 838: Mover disco 2 de auxiliar a origen
# Paso 839: Mover disco 1 de destino a origen
# Paso 840: Mover disco 4 de destino a auxiliar
# Paso 841: Mover disco 1 de origen a auxiliar
# Paso 842: Mover disco 2 de origen a destino
# Paso 843: Mover disco 1 de auxiliar a destino
# Paso 844: Mover disco 3 de origen a auxiliar
# Paso 845: Mover disco 1 de destino a origen
# Paso 846: Mover disco 2 de destino a auxiliar
# Paso 847: Mover disco 1 de origen a auxiliar
# Paso 848: Mover disco 5 de destino a origen
# Paso 849: Mover disco 1 de auxiliar a destino
# Paso 850: Mover disco 2 de auxiliar a origen
# Paso 851: Mover disco 1 de destino a origen
# Paso 852: Mover disco 3 de auxiliar a destino
# Paso 853: Mover disco 1 de origen a auxiliar
# Paso 854: Mover disco 2 de origen a destino
# Paso 855: Mover disco 1 de auxiliar a destino
# Paso 856: Mover disco 4 de auxiliar a origen
# Paso 857: Mover disco 1 de destino a origen
# Paso 858: Mover disco 2 de destino a auxiliar
# Paso 859: Mover disco 1 de origen a auxiliar
# Paso 860: Mover disco 3 de destino a origen
# Paso 861: Mover disco 1 de auxiliar a destino
# Paso 862: Mover disco 2 de auxiliar a origen
# Paso 863: Mover disco 1 de destino a origen
# Paso 864: Mover disco 6 de destino a auxiliar
# Paso 865: Mover disco 1 de origen a auxiliar
# Paso 866: Mover disco 2 de origen a destino
# Paso 867: Mover disco 1 de auxiliar a destino
# Paso 868: Mover disco 3 de origen a auxiliar
# Paso 869: Mover disco 1 de destino a origen
# Paso 870: Mover disco 2 de destino a auxiliar
# Paso 871: Mover disco 1 de origen a auxiliar
# Paso 872: Mover disco 4 de origen a destino
# Paso 873: Mover disco 1 de auxiliar a destino
# Paso 874: Mover disco 2 de auxiliar a origen
# Paso 875: Mover disco 1 de destino a origen
# Paso 876: Mover disco 3 de auxiliar a destino
# Paso 877: Mover disco 1 de origen a auxiliar
# Paso 878: Mover disco 2 de origen a destino
# Paso 879: Mover disco 1 de auxiliar a destino
# Paso 880: Mover disco 5 de origen a auxiliar
# Paso 881: Mover disco 1 de destino a origen
# Paso 882: Mover disco 2 de destino a auxiliar
# Paso 883: Mover disco 1 de origen a auxiliar
# Paso 884: Mover disco 3 de destino a origen
# Paso 885: Mover disco 1 de auxiliar a destino
# Paso 886: Mover disco 2 de auxiliar a origen
# Paso 887: Mover disco 1 de destino a origen
# Paso 888: Mover disco 4 de destino a auxiliar
# Paso 889: Mover disco 1 de origen a auxiliar
# Paso 890: Mover disco 2 de origen a destino
# Paso 891: Mover disco 1 de auxiliar a destino
# Paso 892: Mover disco 3 de origen a auxiliar
# Paso 893: Mover disco 1 de destino a origen
# Paso 894: Mover disco 2 de destino a auxiliar
# Paso 895: Mover disco 1 de origen a auxiliar
# Paso 896: Mover disco 8 de origen a destino
# Paso 897: Mover disco 1 de auxiliar a destino
# Paso 898: Mover disco 2 de auxiliar a origen
# Paso 899: Mover disco 1 de destino a origen
# Paso 900: Mover disco 3 de auxiliar a destino
# Paso 901: Mover disco 1 de origen a auxiliar
# Paso 902: Mover disco 2 de origen a destino
# Paso 903: Mover disco 1 de auxiliar a destino
# Paso 904: Mover disco 4 de auxiliar a origen
# Paso 905: Mover disco 1 de destino a origen
# Paso 906: Mover disco 2 de destino a auxiliar
# Paso 907: Mover disco 1 de origen a auxiliar
# Paso 908: Mover disco 3 de destino a origen
# Paso 909: Mover disco 1 de auxiliar a destino
# Paso 910: Mover disco 2 de auxiliar a origen
# Paso 911: Mover disco 1 de destino a origen
# Paso 912: Mover disco 5 de auxiliar a destino
# Paso 913: Mover disco 1 de origen a auxiliar
# Paso 914: Mover disco 2 de origen a destino
# Paso 915: Mover disco 1 de auxiliar a destino
# Paso 916: Mover disco 3 de origen a auxiliar
# Paso 917: Mover disco 1 de destino a origen
# Paso 918: Mover disco 2 de destino a auxiliar
# Paso 919: Mover disco 1 de origen a auxiliar
# Paso 920: Mover disco 4 de origen a destino
# Paso 921: Mover disco 1 de auxiliar a destino
# Paso 922: Mover disco 2 de auxiliar a origen
# Paso 923: Mover disco 1 de destino a origen
# Paso 924: Mover disco 3 de auxiliar a destino
# Paso 925: Mover disco 1 de origen a auxiliar
# Paso 926: Mover disco 2 de origen a destino
# Paso 927: Mover disco 1 de auxiliar a destino
# Paso 928: Mover disco 6 de auxiliar a origen
# Paso 929: Mover disco 1 de destino a origen
# Paso 930: Mover disco 2 de destino a auxiliar
# Paso 931: Mover disco 1 de origen a auxiliar
# Paso 932: Mover disco 3 de destino a origen
# Paso 933: Mover disco 1 de auxiliar a destino
# Paso 934: Mover disco 2 de auxiliar a origen
# Paso 935: Mover disco 1 de destino a origen
# Paso 936: Mover disco 4 de destino a auxiliar
# Paso 937: Mover disco 1 de origen a auxiliar
# Paso 938: Mover disco 2 de origen a destino
# Paso 939: Mover disco 1 de auxiliar a destino
# Paso 940: Mover disco 3 de origen a auxiliar
# Paso 941: Mover disco 1 de destino a origen
# Paso 942: Mover disco 2 de destino a auxiliar
# Paso 943: Mover disco 1 de origen a auxiliar
# Paso 944: Mover disco 5 de destino a origen
# Paso 945: Mover disco 1 de auxiliar a destino
# Paso 946: Mover disco 2 de auxiliar a origen
# Paso 947: Mover disco 1 de destino a origen
# Paso 948: Mover disco 3 de auxiliar a destino
# Paso 949: Mover disco 1 de origen a auxiliar
# Paso 950: Mover disco 2 de origen a destino
# Paso 951: Mover disco 1 de auxiliar a destino
# Paso 952: Mover disco 4 de auxiliar a origen
# Paso 953: Mover disco 1 de destino a origen
# Paso 954: Mover disco 2 de destino a auxiliar
# Paso 955: Mover disco 1 de origen a auxiliar
# Paso 956: Mover disco 3 de destino a origen
# Paso 957: Mover disco 1 de auxiliar a destino
# Paso 958: Mover disco 2 de auxiliar a origen
# Paso 959: Mover disco 1 de destino a origen
# Paso 960: Mover disco 7 de auxiliar a destino
# Paso 961: Mover disco 1 de origen a auxiliar
# Paso 962: Mover disco 2 de origen a destino
# Paso 963: Mover disco 1 de auxiliar a destino
# Paso 964: Mover disco 3 de origen a auxiliar
# Paso 965: Mover disco 1 de destino a origen
# Paso 966: Mover disco 2 de destino a auxiliar
# Paso 967: Mover disco 1 de origen a auxiliar
# Paso 968: Mover disco 4 de origen a destino
# Paso 969: Mover disco 1 de auxiliar a destino
# Paso 970: Mover disco 2 de auxiliar a origen
# Paso 971: Mover disco 1 de destino a origen
# Paso 972: Mover disco 3 de auxiliar a destino
# Paso 973: Mover disco 1 de origen a auxiliar
# Paso 974: Mover disco 2 de origen a destino
# Paso 975: Mover disco 1 de auxiliar a destino
# Paso 976: Mover disco 5 de origen a auxiliar
# Paso 977: Mover disco 1 de destino a origen
# Paso 978: Mover disco 2 de destino a auxiliar
# Paso 979: Mover disco 1 de origen a auxiliar
# Paso 980: Mover disco 3 de destino a origen
# Paso 981: Mover disco 1 de auxiliar a destino
# Paso 982: Mover disco 2 de auxiliar a origen
# Paso 983: Mover disco 1 de destino a origen
# Paso 984: Mover disco 4 de destino a auxiliar
# Paso 985: Mover disco 1 de origen a auxiliar
# Paso 986: Mover disco 2 de origen a destino
# Paso 987: Mover disco 1 de auxiliar a destino
# Paso 988: Mover disco 3 de origen a auxiliar
# Paso 989: Mover disco 1 de destino a origen
# Paso 990: Mover disco 2 de destino a auxiliar
# Paso 991: Mover disco 1 de origen a auxiliar
# Paso 992: Mover disco 6 de origen a destino
# Paso 993: Mover disco 1 de auxiliar a destino
# Paso 994: Mover disco 2 de auxiliar a origen
# Paso 995: Mover disco 1 de destino a origen
# Paso 996: Mover disco 3 de auxiliar a destino
# Paso 997: Mover disco 1 de origen a auxiliar
# Paso 998: Mover disco 2 de origen a destino
# Paso 999: Mover disco 1 de auxiliar a destino
# Paso 1000: Mover disco 4 de auxiliar a origen
# Paso 1001: Mover disco 1 de destino a origen
# Paso 1002: Mover disco 2 de destino a auxiliar
# Paso 1003: Mover disco 1 de origen a auxiliar
# Paso 1004: Mover disco 3 de destino a origen
# Paso 1005: Mover disco 1 de auxiliar a destino
# Paso 1006: Mover disco 2 de auxiliar a origen
# Paso 1007: Mover disco 1 de destino a origen
# Paso 1008: Mover disco 5 de auxiliar a destino
# Paso 1009: Mover disco 1 de origen a auxiliar
# Paso 1010: Mover disco 2 de origen a destino
# Paso 1011: Mover disco 1 de auxiliar a destino
# Paso 1012: Mover disco 3 de origen a auxiliar
# Paso 1013: Mover disco 1 de destino a origen
# Paso 1014: Mover disco 2 de destino a auxiliar
# Paso 1015: Mover disco 1 de origen a auxiliar
# Paso 1016: Mover disco 4 de origen a destino
# Paso 1017: Mover disco 1 de auxiliar a destino
# Paso 1018: Mover disco 2 de auxiliar a origen
# Paso 1019: Mover disco 1 de destino a origen
# Paso 1020: Mover disco 3 de auxiliar a destino
# Paso 1021: Mover disco 1 de origen a auxiliar
# Paso 1022: Mover disco 2 de origen a destino
# Paso 1023: Mover disco 1 de auxiliar a destino
# Paso 1024: Mover disco 11 de origen a auxiliar
# Paso 1025: Mover disco 1 de destino a origen
# Paso 1026: Mover disco 2 de destino a auxiliar
# Paso 1027: Mover disco 1 de origen a auxiliar
# Paso 1028: Mover disco 3 de destino a origen
# Paso 1029: Mover disco 1 de auxiliar a destino
# Paso 1030: Mover disco 2 de auxiliar a origen
# Paso 1031: Mover disco 1 de destino a origen
# Paso 1032: Mover disco 4 de destino a auxiliar
# Paso 1033: Mover disco 1 de origen a auxiliar
# Paso 1034: Mover disco 2 de origen a destino
# Paso 1035: Mover disco 1 de auxiliar a destino
# Paso 1036: Mover disco 3 de origen a auxiliar
# Paso 1037: Mover disco 1 de destino a origen
# Paso 1038: Mover disco 2 de destino a auxiliar
# Paso 1039: Mover disco 1 de origen a auxiliar
# Paso 1040: Mover disco 5 de destino a origen
# Paso 1041: Mover disco 1 de auxiliar a destino
# Paso 1042: Mover disco 2 de auxiliar a origen
# Paso 1043: Mover disco 1 de destino a origen
# Paso 1044: Mover disco 3 de auxiliar a destino
# Paso 1045: Mover disco 1 de origen a auxiliar
# Paso 1046: Mover disco 2 de origen a destino
# Paso 1047: Mover disco 1 de auxiliar a destino
# Paso 1048: Mover disco 4 de auxiliar a origen
# Paso 1049: Mover disco 1 de destino a origen
# Paso 1050: Mover disco 2 de destino a auxiliar
# Paso 1051: Mover disco 1 de origen a auxiliar
# Paso 1052: Mover disco 3 de destino a origen
# Paso 1053: Mover disco 1 de auxiliar a destino
# Paso 1054: Mover disco 2 de auxiliar a origen
# Paso 1055: Mover disco 1 de destino a origen
# Paso 1056: Mover disco 6 de destino a auxiliar
# Paso 1057: Mover disco 1 de origen a auxiliar
# Paso 1058: Mover disco 2 de origen a destino
# Paso 1059: Mover disco 1 de auxiliar a destino
# Paso 1060: Mover disco 3 de origen a auxiliar
# Paso 1061: Mover disco 1 de destino a origen
# Paso 1062: Mover disco 2 de destino a auxiliar
# Paso 1063: Mover disco 1 de origen a auxiliar
# Paso 1064: Mover disco 4 de origen a destino
# Paso 1065: Mover disco 1 de auxiliar a destino
# Paso 1066: Mover disco 2 de auxiliar a origen
# Paso 1067: Mover disco 1 de destino a origen
# ...
# Paso 3750: Mover disco 2 de destino a auxiliar
# Paso 3751: Mover disco 1 de origen a auxiliar
# Paso 3752: Mover disco 4 de origen a destino
# Paso 3753: Mover disco 1 de auxiliar a destino
# Paso 3754: Mover disco 2 de auxiliar a origen
# Paso 3755: Mover disco 1 de destino a origen
# Paso 3756: Mover disco 3 de auxiliar a destino
# Paso 3757: Mover disco 1 de origen a auxiliar
# Paso 3758: Mover disco 2 de origen a destino
# Paso 3759: Mover disco 1 de auxiliar a destino
# Paso 3760: Mover disco 5 de origen a auxiliar
# Paso 3761: Mover disco 1 de destino a origen
# Paso 3762: Mover disco 2 de destino a auxiliar
# Paso 3763: Mover disco 1 de origen a auxiliar
# Paso 3764: Mover disco 3 de destino a origen
# Paso 3765: Mover disco 1 de auxiliar a destino
# Paso 3766: Mover disco 2 de auxiliar a origen
# Paso 3767: Mover disco 1 de destino a origen
# Paso 3768: Mover disco 4 de destino a auxiliar
# Paso 3769: Mover disco 1 de origen a auxiliar
# Paso 3770: Mover disco 2 de origen a destino
# Paso 3771: Mover disco 1 de auxiliar a destino
# Paso 3772: Mover disco 3 de origen a auxiliar
# Paso 3773: Mover disco 1 de destino a origen
# Paso 3774: Mover disco 2 de destino a auxiliar
# Paso 3775: Mover disco 1 de origen a auxiliar
# Paso 3776: Mover disco 7 de destino a origen
# Paso 3777: Mover disco 1 de auxiliar a destino
# Paso 3778: Mover disco 2 de auxiliar a origen
# Paso 3779: Mover disco 1 de destino a origen
# Paso 3780: Mover disco 3 de auxiliar a destino
# Paso 3781: Mover disco 1 de origen a auxiliar
# Paso 3782: Mover disco 2 de origen a destino
# Paso 3783: Mover disco 1 de auxiliar a destino
# Paso 3784: Mover disco 4 de auxiliar a origen
# Paso 3785: Mover disco 1 de destino a origen
# Paso 3786: Mover disco 2 de destino a auxiliar
# Paso 3787: Mover disco 1 de origen a auxiliar
# Paso 3788: Mover disco 3 de destino a origen
# Paso 3789: Mover disco 1 de auxiliar a destino
# Paso 3790: Mover disco 2 de auxiliar a origen
# Paso 3791: Mover disco 1 de destino a origen
# Paso 3792: Mover disco 5 de auxiliar a destino
# Paso 3793: Mover disco 1 de origen a auxiliar
# Paso 3794: Mover disco 2 de origen a destino
# Paso 3795: Mover disco 1 de auxiliar a destino
# Paso 3796: Mover disco 3 de origen a auxiliar
# Paso 3797: Mover disco 1 de destino a origen
# Paso 3798: Mover disco 2 de destino a auxiliar
# Paso 3799: Mover disco 1 de origen a auxiliar
# Paso 3800: Mover disco 4 de origen a destino
# Paso 3801: Mover disco 1 de auxiliar a destino
# Paso 3802: Mover disco 2 de auxiliar a origen
# Paso 3803: Mover disco 1 de destino a origen
# Paso 3804: Mover disco 3 de auxiliar a destino
# Paso 3805: Mover disco 1 de origen a auxiliar
# Paso 3806: Mover disco 2 de origen a destino
# Paso 3807: Mover disco 1 de auxiliar a destino
# Paso 3808: Mover disco 6 de auxiliar a origen
# Paso 3809: Mover disco 1 de destino a origen
# Paso 3810: Mover disco 2 de destino a auxiliar
# Paso 3811: Mover disco 1 de origen a auxiliar
# Paso 3812: Mover disco 3 de destino a origen
# Paso 3813: Mover disco 1 de auxiliar a destino
# Paso 3814: Mover disco 2 de auxiliar a origen
# Paso 3815: Mover disco 1 de destino a origen
# Paso 3816: Mover disco 4 de destino a auxiliar
# Paso 3817: Mover disco 1 de origen a auxiliar
# Paso 3818: Mover disco 2 de origen a destino
# Paso 3819: Mover disco 1 de auxiliar a destino
# Paso 3820: Mover disco 3 de origen a auxiliar
# Paso 3821: Mover disco 1 de destino a origen
# Paso 3822: Mover disco 2 de destino a auxiliar
# Paso 3823: Mover disco 1 de origen a auxiliar
# Paso 3824: Mover disco 5 de destino a origen
# Paso 3825: Mover disco 1 de auxiliar a destino
# Paso 3826: Mover disco 2 de auxiliar a origen
# Paso 3827: Mover disco 1 de destino a origen
# Paso 3828: Mover disco 3 de auxiliar a destino
# Paso 3829: Mover disco 1 de origen a auxiliar
# Paso 3830: Mover disco 2 de origen a destino
# Paso 3831: Mover disco 1 de auxiliar a destino
# Paso 3832: Mover disco 4 de auxiliar a origen
# Paso 3833: Mover disco 1 de destino a origen
# Paso 3834: Mover disco 2 de destino a auxiliar
# Paso 3835: Mover disco 1 de origen a auxiliar
# Paso 3836: Mover disco 3 de destino a origen
# Paso 3837: Mover disco 1 de auxiliar a destino
# Paso 3838: Mover disco 2 de auxiliar a origen
# Paso 3839: Mover disco 1 de destino a origen
# Paso 3840: Mover disco 9 de auxiliar a destino
# Paso 3841: Mover disco 1 de origen a auxiliar
# Paso 3842: Mover disco 2 de origen a destino
# Paso 3843: Mover disco 1 de auxiliar a destino
# Paso 3844: Mover disco 3 de origen a auxiliar
# Paso 3845: Mover disco 1 de destino a origen
# Paso 3846: Mover disco 2 de destino a auxiliar
# Paso 3847: Mover disco 1 de origen a auxiliar
# Paso 3848: Mover disco 4 de origen a destino
# Paso 3849: Mover disco 1 de auxiliar a destino
# Paso 3850: Mover disco 2 de auxiliar a origen
# Paso 3851: Mover disco 1 de destino a origen
# Paso 3852: Mover disco 3 de auxiliar a destino
# Paso 3853: Mover disco 1 de origen a auxiliar
# Paso 3854: Mover disco 2 de origen a destino
# Paso 3855: Mover disco 1 de auxiliar a destino
# Paso 3856: Mover disco 5 de origen a auxiliar
# Paso 3857: Mover disco 1 de destino a origen
# Paso 3858: Mover disco 2 de destino a auxiliar
# Paso 3859: Mover disco 1 de origen a auxiliar
# Paso 3860: Mover disco 3 de destino a origen
# Paso 3861: Mover disco 1 de auxiliar a destino
# Paso 3862: Mover disco 2 de auxiliar a origen
# Paso 3863: Mover disco 1 de destino a origen
# Paso 3864: Mover disco 4 de destino a auxiliar
# Paso 3865: Mover disco 1 de origen a auxiliar
# Paso 3866: Mover disco 2 de origen a destino
# Paso 3867: Mover disco 1 de auxiliar a destino
# Paso 3868: Mover disco 3 de origen a auxiliar
# Paso 3869: Mover disco 1 de destino a origen
# Paso 3870: Mover disco 2 de destino a auxiliar
# Paso 3871: Mover disco 1 de origen a auxiliar
# Paso 3872: Mover disco 6 de origen a destino
# Paso 3873: Mover disco 1 de auxiliar a destino
# Paso 3874: Mover disco 2 de auxiliar a origen
# Paso 3875: Mover disco 1 de destino a origen
# Paso 3876: Mover disco 3 de auxiliar a destino
# Paso 3877: Mover disco 1 de origen a auxiliar
# Paso 3878: Mover disco 2 de origen a destino
# Paso 3879: Mover disco 1 de auxiliar a destino
# Paso 3880: Mover disco 4 de auxiliar a origen
# Paso 3881: Mover disco 1 de destino a origen
# Paso 3882: Mover disco 2 de destino a auxiliar
# Paso 3883: Mover disco 1 de origen a auxiliar
# Paso 3884: Mover disco 3 de destino a origen
# Paso 3885: Mover disco 1 de auxiliar a destino
# Paso 3886: Mover disco 2 de auxiliar a origen
# Paso 3887: Mover disco 1 de destino a origen
# Paso 3888: Mover disco 5 de auxiliar a destino
# Paso 3889: Mover disco 1 de origen a auxiliar
# Paso 3890: Mover disco 2 de origen a destino
# Paso 3891: Mover disco 1 de auxiliar a destino
# Paso 3892: Mover disco 3 de origen a auxiliar
# Paso 3893: Mover disco 1 de destino a origen
# Paso 3894: Mover disco 2 de destino a auxiliar
# Paso 3895: Mover disco 1 de origen a auxiliar
# Paso 3896: Mover disco 4 de origen a destino
# Paso 3897: Mover disco 1 de auxiliar a destino
# Paso 3898: Mover disco 2 de auxiliar a origen
# Paso 3899: Mover disco 1 de destino a origen
# Paso 3900: Mover disco 3 de auxiliar a destino
# Paso 3901: Mover disco 1 de origen a auxiliar
# Paso 3902: Mover disco 2 de origen a destino
# Paso 3903: Mover disco 1 de auxiliar a destino
# Paso 3904: Mover disco 7 de origen a auxiliar
# Paso 3905: Mover disco 1 de destino a origen
# Paso 3906: Mover disco 2 de destino a auxiliar
# Paso 3907: Mover disco 1 de origen a auxiliar
# Paso 3908: Mover disco 3 de destino a origen
# Paso 3909: Mover disco 1 de auxiliar a destino
# Paso 3910: Mover disco 2 de auxiliar a origen
# Paso 3911: Mover disco 1 de destino a origen
# Paso 3912: Mover disco 4 de destino a auxiliar
# Paso 3913: Mover disco 1 de origen a auxiliar
# Paso 3914: Mover disco 2 de origen a destino
# Paso 3915: Mover disco 1 de auxiliar a destino
# Paso 3916: Mover disco 3 de origen a auxiliar
# Paso 3917: Mover disco 1 de destino a origen
# Paso 3918: Mover disco 2 de destino a auxiliar
# Paso 3919: Mover disco 1 de origen a auxiliar
# Paso 3920: Mover disco 5 de destino a origen
# Paso 3921: Mover disco 1 de auxiliar a destino
# Paso 3922: Mover disco 2 de auxiliar a origen
# Paso 3923: Mover disco 1 de destino a origen
# Paso 3924: Mover disco 3 de auxiliar a destino
# Paso 3925: Mover disco 1 de origen a auxiliar
# Paso 3926: Mover disco 2 de origen a destino
# Paso 3927: Mover disco 1 de auxiliar a destino
# Paso 3928: Mover disco 4 de auxiliar a origen
# Paso 3929: Mover disco 1 de destino a origen
# Paso 3930: Mover disco 2 de destino a auxiliar
# Paso 3931: Mover disco 1 de origen a auxiliar
# Paso 3932: Mover disco 3 de destino a origen
# Paso 3933: Mover disco 1 de auxiliar a destino
# Paso 3934: Mover disco 2 de auxiliar a origen
# Paso 3935: Mover disco 1 de destino a origen
# Paso 3936: Mover disco 6 de destino a auxiliar
# Paso 3937: Mover disco 1 de origen a auxiliar
# Paso 3938: Mover disco 2 de origen a destino
# Paso 3939: Mover disco 1 de auxiliar a destino
# Paso 3940: Mover disco 3 de origen a auxiliar
# Paso 3941: Mover disco 1 de destino a origen
# Paso 3942: Mover disco 2 de destino a auxiliar
# Paso 3943: Mover disco 1 de origen a auxiliar
# Paso 3944: Mover disco 4 de origen a destino
# Paso 3945: Mover disco 1 de auxiliar a destino
# Paso 3946: Mover disco 2 de auxiliar a origen
# Paso 3947: Mover disco 1 de destino a origen
# Paso 3948: Mover disco 3 de auxiliar a destino
# Paso 3949: Mover disco 1 de origen a auxiliar
# Paso 3950: Mover disco 2 de origen a destino
# Paso 3951: Mover disco 1 de auxiliar a destino
# Paso 3952: Mover disco 5 de origen a auxiliar
# Paso 3953: Mover disco 1 de destino a origen
# Paso 3954: Mover disco 2 de destino a auxiliar
# Paso 3955: Mover disco 1 de origen a auxiliar
# Paso 3956: Mover disco 3 de destino a origen
# Paso 3957: Mover disco 1 de auxiliar a destino
# Paso 3958: Mover disco 2 de auxiliar a origen
# Paso 3959: Mover disco 1 de destino a origen
# Paso 3960: Mover disco 4 de destino a auxiliar
# Paso 3961: Mover disco 1 de origen a auxiliar
# Paso 3962: Mover disco 2 de origen a destino
# Paso 3963: Mover disco 1 de auxiliar a destino
# Paso 3964: Mover disco 3 de origen a auxiliar
# Paso 3965: Mover disco 1 de destino a origen
# Paso 3966: Mover disco 2 de destino a auxiliar
# Paso 3967: Mover disco 1 de origen a auxiliar
# Paso 3968: Mover disco 8 de origen a destino
# Paso 3969: Mover disco 1 de auxiliar a destino
# Paso 3970: Mover disco 2 de auxiliar a origen
# Paso 3971: Mover disco 1 de destino a origen
# Paso 3972: Mover disco 3 de auxiliar a destino
# Paso 3973: Mover disco 1 de origen a auxiliar
# Paso 3974: Mover disco 2 de origen a destino
# Paso 3975: Mover disco 1 de auxiliar a destino
# Paso 3976: Mover disco 4 de auxiliar a origen
# Paso 3977: Mover disco 1 de destino a origen
# Paso 3978: Mover disco 2 de destino a auxiliar
# Paso 3979: Mover disco 1 de origen a auxiliar
# Paso 3980: Mover disco 3 de destino a origen
# Paso 3981: Mover disco 1 de auxiliar a destino
# Paso 3982: Mover disco 2 de auxiliar a origen
# Paso 3983: Mover disco 1 de destino a origen
# Paso 3984: Mover disco 5 de auxiliar a destino
# Paso 3985: Mover disco 1 de origen a auxiliar
# Paso 3986: Mover disco 2 de origen a destino
# Paso 3987: Mover disco 1 de auxiliar a destino
# Paso 3988: Mover disco 3 de origen a auxiliar
# Paso 3989: Mover disco 1 de destino a origen
# Paso 3990: Mover disco 2 de destino a auxiliar
# Paso 3991: Mover disco 1 de origen a auxiliar
# Paso 3992: Mover disco 4 de origen a destino
# Paso 3993: Mover disco 1 de auxiliar a destino
# Paso 3994: Mover disco 2 de auxiliar a origen
# Paso 3995: Mover disco 1 de destino a origen
# Paso 3996: Mover disco 3 de auxiliar a destino
# Paso 3997: Mover disco 1 de origen a auxiliar
# Paso 3998: Mover disco 2 de origen a destino
# Paso 3999: Mover disco 1 de auxiliar a destino
# Paso 4000: Mover disco 6 de auxiliar a origen
# Paso 4001: Mover disco 1 de destino a origen
# Paso 4002: Mover disco 2 de destino a auxiliar
# Paso 4003: Mover disco 1 de origen a auxiliar
# Paso 4004: Mover disco 3 de destino a origen
# Paso 4005: Mover disco 1 de auxiliar a destino
# Paso 4006: Mover disco 2 de auxiliar a origen
# Paso 4007: Mover disco 1 de destino a origen
# Paso 4008: Mover disco 4 de destino a auxiliar
# Paso 4009: Mover disco 1 de origen a auxiliar
# Paso 4010: Mover disco 2 de origen a destino
# Paso 4011: Mover disco 1 de auxiliar a destino
# Paso 4012: Mover disco 3 de origen a auxiliar
# Paso 4013: Mover disco 1 de destino a origen
# Paso 4014: Mover disco 2 de destino a auxiliar
# Paso 4015: Mover disco 1 de origen a auxiliar
# Paso 4016: Mover disco 5 de destino a origen
# Paso 4017: Mover disco 1 de auxiliar a destino
# Paso 4018: Mover disco 2 de auxiliar a origen
# Paso 4019: Mover disco 1 de destino a origen
# Paso 4020: Mover disco 3 de auxiliar a destino
# Paso 4021: Mover disco 1 de origen a auxiliar
# Paso 4022: Mover disco 2 de origen a destino
# Paso 4023: Mover disco 1 de auxiliar a destino
# Paso 4024: Mover disco 4 de auxiliar a origen
# Paso 4025: Mover disco 1 de destino a origen
# Paso 4026: Mover disco 2 de destino a auxiliar
# Paso 4027: Mover disco 1 de origen a auxiliar
# Paso 4028: Mover disco 3 de destino a origen
# Paso 4029: Mover disco 1 de auxiliar a destino
# Paso 4030: Mover disco 2 de auxiliar a origen
# Paso 4031: Mover disco 1 de destino a origen
# Paso 4032: Mover disco 7 de auxiliar a destino
# Paso 4033: Mover disco 1 de origen a auxiliar
# Paso 4034: Mover disco 2 de origen a destino
# Paso 4035: Mover disco 1 de auxiliar a destino
# Paso 4036: Mover disco 3 de origen a auxiliar
# Paso 4037: Mover disco 1 de destino a origen
# Paso 4038: Mover disco 2 de destino a auxiliar
# Paso 4039: Mover disco 1 de origen a auxiliar
# Paso 4040: Mover disco 4 de origen a destino
# Paso 4041: Mover disco 1 de auxiliar a destino
# Paso 4042: Mover disco 2 de auxiliar a origen
# Paso 4043: Mover disco 1 de destino a origen
# Paso 4044: Mover disco 3 de auxiliar a destino
# Paso 4045: Mover disco 1 de origen a auxiliar
# Paso 4046: Mover disco 2 de origen a destino
# Paso 4047: Mover disco 1 de auxiliar a destino
# Paso 4048: Mover disco 5 de origen a auxiliar
# Paso 4049: Mover disco 1 de destino a origen
# Paso 4050: Mover disco 2 de destino a auxiliar
# Paso 4051: Mover disco 1 de origen a auxiliar
# Paso 4052: Mover disco 3 de destino a origen
# Paso 4053: Mover disco 1 de auxiliar a destino
# Paso 4054: Mover disco 2 de auxiliar a origen
# Paso 4055: Mover disco 1 de destino a origen
# Paso 4056: Mover disco 4 de destino a auxiliar
# Paso 4057: Mover disco 1 de origen a auxiliar
# Paso 4058: Mover disco 2 de origen a destino
# Paso 4059: Mover disco 1 de auxiliar a destino
# Paso 4060: Mover disco 3 de origen a auxiliar
# Paso 4061: Mover disco 1 de destino a origen
# Paso 4062: Mover disco 2 de destino a auxiliar
# Paso 4063: Mover disco 1 de origen a auxiliar
# Paso 4064: Mover disco 6 de origen a destino
# Paso 4065: Mover disco 1 de auxiliar a destino
# Paso 4066: Mover disco 2 de auxiliar a origen
# Paso 4067: Mover disco 1 de destino a origen
# Paso 4068: Mover disco 3 de auxiliar a destino
# Paso 4069: Mover disco 1 de origen a auxiliar
# Paso 4070: Mover disco 2 de origen a destino
# Paso 4071: Mover disco 1 de auxiliar a destino
# Paso 4072: Mover disco 4 de auxiliar a origen
# Paso 4073: Mover disco 1 de destino a origen
# Paso 4074: Mover disco 2 de destino a auxiliar
# Paso 4075: Mover disco 1 de origen a auxiliar
# Paso 4076: Mover disco 3 de destino a origen
# Paso 4077: Mover disco 1 de auxiliar a destino
# Paso 4078: Mover disco 2 de auxiliar a origen
# Paso 4079: Mover disco 1 de destino a origen
# Paso 4080: Mover disco 5 de auxiliar a destino
# Paso 4081: Mover disco 1 de origen a auxiliar
# Paso 4082: Mover disco 2 de origen a destino
# Paso 4083: Mover disco 1 de auxiliar a destino
# Paso 4084: Mover disco 3 de origen a auxiliar
# Paso 4085: Mover disco 1 de destino a origen
# Paso 4086: Mover disco 2 de destino a auxiliar
# Paso 4087: Mover disco 1 de origen a auxiliar
# Paso 4088: Mover disco 4 de origen a destino
# Paso 4089: Mover disco 1 de auxiliar a destino
# Paso 4090: Mover disco 2 de auxiliar a origen
# Paso 4091: Mover disco 1 de destino a origen
# Paso 4092: Mover disco 3 de auxiliar a destino
# Paso 4093: Mover disco 1 de origen a auxiliar
# Paso 4094: Mover disco 2 de origen a destino
# Paso 4095: Mover disco 1 de auxiliar a destino
# Una torre de Hanoi de 12 discos puede resolverse en 4095 pasos.
# 4095

# %%
# Revisamos que cumple con la expresion no recursiva 2^n - 1

for n in range(1, 25):
  pasos = TorresdeHanoi(n, mostrar_torres = False, mostrar_pasos = False)
  assert pasos == 2**n - 1
  print(n, pasos, 2**n - 1)
# Out:
# 1 1 1
# 2 3 3
# 3 7 7
# 4 15 15
# 5 31 31
# 6 63 63
# 7 127 127
# 8 255 255
# 9 511 511
# 10 1023 1023
# 11 2047 2047
# 12 4095 4095
# 13 8191 8191
# 14 16383 16383
# 15 32767 32767
# 16 65535 65535
# 17 131071 131071
# 18 262143 262143
# 19 524287 524287
# 20 1048575 1048575
# 21 2097151 2097151
# 22 4194303 4194303
# 23 8388607 8388607
# 24 16777215 16777215
